# %% [markdown]
# # Evaluation Project 3-4 Zomato Restaurant

# %% [markdown]
# # BY: Aakash bindal

# %% [markdown]
# # BATCH NO:DS2401

# %% [markdown]
# # Project Description
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.

# %% [markdown]
# # Data Storage:
#
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
#
# Country_code.csv contains two variables:
#
# • Country code
#
# • Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following
#
# variables:
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world
#
# • Restaurant Name: Name of the restaurant
#
# • Country Code: Country in which restaurant is located
#
# • City: City in which restaurant is located
#
# • Address: Address of the restaurant
#
# • Locality: Location in the city
#
# • Locality Verbose: Detailed description of the locality
#
# • Longitude: Longitude coordinate of the restaurant&#39;s location
#
# • Latitude: Latitude coordinate of the restaurant&#39;s location
#
# • Cuisines: Cuisines offered by the restaurant
#
# • Average Cost for two: Cost for two people in different currencies ��
#
# • Currency: Currency of the country
#
# • Has Table booking: yes/no
#
# • Has Online delivery: yes/ no
#
# • Is delivering: yes/ no
#
# • Switch to order menu: yes/no
#
# • Price range: range of price of food
#
# • Aggregate Rating: Average rating out of 5
#
# • Rating color: depending upon the average rating color
#
# • Rating text: text on the basis of rating of rating
#
# • Votes: Number of ratings casted by people

# %% [markdown]
# # Problem statement : In this dataset predict 2 things –
#
# 1) Average Cost for two
#
# 2) Price range
#
#
# Hint : Use pandas methods to combine all the datasets and then start working on this project

# %%
#importing required Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
excel_url = 'https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/Country-Code.xlsx'
csv_url = 'https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/zomato.csv'

# Reading the files
z1 = pd.read_excel(excel_url, engine='openpyxl') 
z2 = pd.read_csv(csv_url, encoding="ISO-8859-1")
z2
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                    Karakí_y
# 9547                                   Koôuyolu
# 9548                                 Kuruí_eôme
# 9549                                 Kuruí_eôme
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                                Karakí_y, ÛÁstanbul   28.977392
# 9547                               Koôuyolu, ÛÁstanbul   29.041297
# 9548                             Kuruí_eôme, ÛÁstanbul   29.034640
# 9549                             Kuruí_eôme, ÛÁstanbul   29.036019
# 9550                                    Moda, ÛÁstanbul   29.026016
#
#        Latitude                          Cuisines  ...          Currency  \
# 0     14.565443        French, Japanese, Desserts  ...  Botswana Pula(P)
# 1     14.553708                          Japanese  ...  Botswana Pula(P)
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)
# 3     14.585318                   Japanese, Sushi  ...  Botswana Pula(P)
# 4     14.584450                  Japanese, Korean  ...  Botswana Pula(P)
# ...         ...                               ...  ...               ...
# 9546  41.022793                           Turkish  ...  Turkish Lira(TL)
# 9547  41.009847   World Cuisine, Patisserie, Cafe  ...  Turkish Lira(TL)
# 9548  41.055817            Italian, World Cuisine  ...  Turkish Lira(TL)
# 9549  41.057979                   Restaurant Cafe  ...  Turkish Lira(TL)
# 9550  40.984776                              Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 0                  Yes                  No                No
# 1                  Yes                  No                No
# 2                  Yes                  No                No
# 3                   No                  No                No
# 4                  Yes                  No                No
# ...                ...                 ...               ...
# 9546                No                  No                No
# 9547                No                  No                No
# 9548                No                  No                No
# 9549                No                  No                No
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 0                      No           3               4.8    Dark Green
# 1                      No           3               4.5    Dark Green
# 2                      No           4               4.4         Green
# 3                      No           4               4.9    Dark Green
# 4                      No           4               4.8    Dark Green
# ...                   ...         ...               ...           ...
# 9546                   No           3               4.1         Green
# 9547                   No           3               4.2         Green
# 9548                   No           4               3.7        Yellow
# 9549                   No           4               4.0         Green
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 0      Excellent   314
# 1      Excellent   591
# 2      Very Good   270
# 3      Excellent   365
# 4      Excellent   229
# ...          ...   ...
# 9546   Very Good   788
# 9547   Very Good  1034
# 9548        Good   661
# 9549   Very Good   901
# 9550   Very Good   591
#
# [9551 rows x 21 columns]

# %%
# Checking the shape of the dataset-
print("Number of rows in the given dataset:",z1.shape[0])
print("Number of columns in the given dataset:",z1.shape[1])
# Out:
# Number of rows in the given dataset: 15
# Number of columns in the given dataset: 2

# %%
# Checking the shape of the dataset-
print("Number of rows in the given dataset:",z2.shape[0])
print("Number of columns in the given dataset:",z2.shape[1])
# Out:
# Number of rows in the given dataset: 9551
# Number of columns in the given dataset: 21

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Checking the features present in the z2
z2.columns.to_list()
# Out:
# ['Restaurant ID',
#  'Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes']

# %%
# Checking the features present in the z1
z1.columns
# Out:
# Index(['Country Code', 'Country'], dtype='object')

# %% [markdown]
# # Merging the dataset

# %%
# Merging the dataset
zomato = pd.merge(z1,z2)
zomato.head(3)
# Out:
#    Country Code Country  Restaurant ID          Restaurant Name  City  \
# 0             1   India        3400025               Jahanpanah  Agra
# 1             1   India        3400341      Rangrezz Restaurant  Agra
# 2             1   India        3400005  Time2Eat - Mama Chicken  Agra
#
#                                              Address    Locality  \
# 0  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra Cantt
# 1  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra Cantt
# 2        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra Cantt
#
#    Locality Verbose  Longitude   Latitude  ...            Currency  \
# 0  Agra Cantt, Agra  78.011544  27.161661  ...  Indian Rupees(Rs.)
# 1  Agra Cantt, Agra   0.000000   0.000000  ...  Indian Rupees(Rs.)
# 2  Agra Cantt, Agra  78.011608  27.160832  ...  Indian Rupees(Rs.)
#
#    Has Table booking Has Online delivery Is delivering now  \
# 0                 No                  No                No
# 1                 No                  No                No
# 2                 No                  No                No
#
#   Switch to order menu Price range Aggregate rating  Rating color  \
# 0                   No           3              3.9        Yellow
# 1                   No           2              3.5        Yellow
# 2                   No           2              3.6        Yellow
#
#    Rating text Votes
# 0         Good   140
# 1         Good    71
# 2         Good    94
#
# [3 rows x 22 columns]

# %%
# Checking the dimension of the zomato 

zomato.shape
# Out:
# (9551, 22)

# %%
# Checking the features present in the dataset
zomato.columns.to_list()
# Out:
# ['Country Code',
#  'Country',
#  'Restaurant ID',
#  'Restaurant Name',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes']

# %%
#Checking the data types of all the features-
zomato.dtypes
# Out:
# Country Code              int64
# Country                  object
# Restaurant ID             int64
# Restaurant Name          object
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %% [markdown]
# There are 22 attributes with contains (5)integer,(14) object and (3) float datatypes.

# %%
# Checking the information about the dataset
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9551 non-null   int64
#  1   Country               9551 non-null   object
#  2   Restaurant ID         9551 non-null   int64
#  3   Restaurant Name       9551 non-null   object
#  4   City                  9551 non-null   object
#  5   Address               9551 non-null   object
#  6   Locality              9551 non-null   object
#  7   Locality Verbose      9551 non-null   object
#  8   Longitude             9551 non-null   float64
#  9   Latitude              9551 non-null   float64
#  10  Cuisines              9542 non-null   object
#  11  Average Cost for two  9551 non-null   int64
#  12  Currency              9551 non-null   object
#  13  Has Table booking     9551 non-null   object
#  14  Has Online delivery   9551 non-null   object
#  15  Is delivering now     9551 non-null   object
#  16  Switch to order menu  9551 non-null   object
#  17  Price range           9551 non-null   int64
#  18  Aggregate rating      9551 non-null   float64
#  19  Rating color          9551 non-null   object
#  20  Rating text           9551 non-null   object
#  21  Votes                 9551 non-null   int64
# dtypes: float64(3), int64(5), object(14)
# memory usage: 1.7+ MB

# %% [markdown]
#  'Cuisines' has 9542 values which means that there is Missing valuesprsent in this column.

# %%
#Checking the nunique values 

zomato.nunique().to_frame('Number of unique values')
# Out:
#                       Number of unique values
# Country Code                               15
# Country                                    15
# Restaurant ID                            9551
# Restaurant Name                          7446
# City                                      141
# Address                                  8918
# Locality                                 1208
# Locality Verbose                         1265
# Longitude                                8120
# Latitude                                 8677
# Cuisines                                 1825
# Average Cost for two                      140
# Currency                                   12
# Has Table booking                           2
# Has Online delivery                         2
# Is delivering now                           2
# Switch to order menu                        1
# Price range                                 4
# Aggregate rating                           33
# Rating color                                6
# Rating text                                 6
# Votes                                    1012

# %%
#checking the value count for each columns

for col in zomato.columns:   
    print('--' * 20 + col + '--' * 20)
    display(zomato[col].value_counts().head())
# Out:
# ----------------------------------------Country Code----------------------------------------
# 1      8652
# 216     434
# 215      80
# 30       60
# 189      60
# Name: Country Code, dtype: int64
# ----------------------------------------Country----------------------------------------
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# Name: Country, dtype: int64
# ----------------------------------------Restaurant ID----------------------------------------
# 3400025     1
# 309811      1
# 18460981    1
# 18287389    1
# 1629        1
# Name: Restaurant ID, dtype: int64
# ----------------------------------------Restaurant Name----------------------------------------
# Cafe Coffee Day     83
# Domino's Pizza      79
# Subway              63
# Green Chick Chop    51
# McDonald's          48
# Name: Restaurant Name, dtype: int64
# ----------------------------------------City----------------------------------------
# New Delhi    5473
# Gurgaon      1118
# Noida        1080
# Faridabad     251
# Ghaziabad      25
# Name: City, dtype: int64
# ----------------------------------------Address----------------------------------------
# Sector 41, Noida                                            11
# Dilli Haat, INA, New Delhi                                  11
# Greater Kailash (GK) 1, New Delhi                           10
# The Imperial, Janpath, New Delhi                             9
# The Lalit, Barakhamba Avenue, Barakhamba Road, New Delhi     8
# Name: Address, dtype: int64
# ----------------------------------------Locality----------------------------------------
# Connaught Place    122
# Rajouri Garden      99
# Shahdara            87
# Defence Colony      86
# Pitampura           85
# Name: Locality, dtype: int64
# ----------------------------------------Locality Verbose----------------------------------------
# Connaught Place, New Delhi    122
# Rajouri Garden, New Delhi      99
# Shahdara, New Delhi            87
# Defence Colony, New Delhi      86
# Pitampura, New Delhi           85
# Name: Locality Verbose, dtype: int64
# ----------------------------------------Longitude----------------------------------------
# 0.000000     498
# 77.353663     19
# 77.230412     12
# 77.088688     10
# 77.251426      9
# Name: Longitude, dtype: int64
# ----------------------------------------Latitude----------------------------------------
# 0.000000     498
# 28.574309     16
# 28.551456      9
# 28.574300      9
# 28.597103      8
# Name: Latitude, dtype: int64
# ----------------------------------------Cuisines----------------------------------------
# North Indian             936
# North Indian, Chinese    511
# Fast Food                354
# Chinese                  354
# North Indian, Mughlai    334
# Name: Cuisines, dtype: int64
# ----------------------------------------Average Cost for two----------------------------------------
# 500    900
# 300    897
# 400    857
# 200    687
# 600    652
# Name: Average Cost for two, dtype: int64
# ----------------------------------------Currency----------------------------------------
# Indian Rupees(Rs.)    8652
# Dollar($)              482
# Pounds(£)              80
# Brazilian Real(R$)      60
# Rand(R)                 60
# Name: Currency, dtype: int64
# ----------------------------------------Has Table booking----------------------------------------
# No     8393
# Yes    1158
# Name: Has Table booking, dtype: int64
# ----------------------------------------Has Online delivery----------------------------------------
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64
# ----------------------------------------Is delivering now----------------------------------------
# No     9517
# Yes      34
# Name: Is delivering now, dtype: int64
# ----------------------------------------Switch to order menu----------------------------------------
# No    9551
# Name: Switch to order menu, dtype: int64
# ----------------------------------------Price range----------------------------------------
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64
# ----------------------------------------Aggregate rating----------------------------------------
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# Name: Aggregate rating, dtype: int64
# ----------------------------------------Rating color----------------------------------------
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Name: Rating color, dtype: int64
# ----------------------------------------Rating text----------------------------------------
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Name: Rating text, dtype: int64
# ----------------------------------------Votes----------------------------------------
# 0    1094
# 1     483
# 2     327
# 3     244
# 4     207
# Name: Votes, dtype: int64

# %% [markdown]
# # Checking Null and Duplicates Values

# %%
print(zomato.isna().sum())
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Checking for missing values in the dataset-
    
plt.figure(figsize=[9,9])
sns.heatmap(zomato.isnull(),cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# only cuisinies have null values present

# %%
#checking the unique values present in the columns 'Cuisines'

zomato['Cuisines'].unique()
# Out:
# array(['North Indian, Mughlai', 'North Indian', 'Rajasthani', ...,
#        'Coffee and Tea, Desserts, Beverages', 'Sandwich, Sushi, Tapas',
#        'Burger, Greek, Sandwich'], dtype=object)

# %%
# Drop the null values & Check for null values

zomato.dropna(subset = ['Cuisines'],inplace = True)
zomato.isnull().sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# After dropping the null values, there are no null values remaining.

# %%
#checking for duplicated values
zomato.duplicated().sum()
# Out:
# 0

# %%
# Now lets check how many outlets are on Zomato

zomato['Restaurant Name'].value_counts()
# Out:
# Cafe Coffee Day                83
# Domino's Pizza                 79
# Subway                         63
# Green Chick Chop               51
# McDonald's                     48
#                                ..
# Cafe on 3 - Holiday Inn         1
# Viva Deli - Holiday Inn         1
# Rang De Basanti Urban Dhaba     1
# Lord of the Drinks Meadow       1
# Fishpatrick's Crabby Cafe       1
# Name: Restaurant Name, Length: 7437, dtype: int64

# %%
# Dropping features Restaurant ID, Locality, Switch to order menu, Rating color, Address, Country Code

zomato.drop(['Restaurant ID','Locality','Switch to order menu','Rating color','Address','Country Code'],axis=1,inplace=True)

# %%
# Checking the dimension of the dataset

zomato.shape
# Out:
# (9542, 16)

# %% [markdown]
# # Splitting the dataset into Categorical and Numerical

# %%
# Splitting the dataset into Categorical and Numerical

cat_col=[]

for i in zomato.columns:
    if zomato[i].dtypes == 'object':
        cat_col.append(i)
        
num_col=[]

for i in zomato.columns:
    if zomato[i].dtypes != 'object':
        num_col.append(i)

# %%
cat_col
# Out:
# ['Country',
#  'Restaurant Name',
#  'City',
#  'Locality Verbose',
#  'Cuisines',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Rating text']

# %%
num_col
# Out:
# ['Longitude',
#  'Latitude',
#  'Average Cost for two',
#  'Price range',
#  'Aggregate rating',
#  'Votes']

# %%
#Checking the statistical summary
zomato.describe(include='object')
# Out:
#        Country  Restaurant Name       City            Locality Verbose  \
# count     9542             9542       9542                        9542
# unique      15             7437        140                        1263
# top      India  Cafe Coffee Day  New Delhi  Connaught Place, New Delhi
# freq      8652               83       5473                         122
#
#             Cuisines            Currency Has Table booking  \
# count           9542                9542              9542
# unique          1825                  12                 2
# top     North Indian  Indian Rupees(Rs.)                No
# freq             936                8652              8384
#
#        Has Online delivery Is delivering now Rating text
# count                 9542              9542        9542
# unique                   2                 2           6
# top                     No                No     Average
# freq                  7091              9508        3734

# %%
zomato.describe()
# Out:
#          Longitude     Latitude  Average Cost for two  Price range  \
# count  9542.000000  9542.000000           9542.000000  9542.000000
# mean     64.274997    25.848532           1200.326137     1.804968
# std      41.197602    11.010094          16128.743876     0.905563
# min    -157.948486   -41.330428              0.000000     1.000000
# 25%      77.081565    28.478658            250.000000     1.000000
# 50%      77.192031    28.570444            400.000000     2.000000
# 75%      77.282043    28.642711            700.000000     2.000000
# max     174.832089    55.976980         800000.000000     4.000000
#
#        Aggregate rating         Votes
# count       9542.000000   9542.000000
# mean           2.665238    156.772060
# std            1.516588    430.203324
# min            0.000000      0.000000
# 25%            2.500000      5.000000
# 50%            3.200000     31.000000
# 75%            3.700000    130.000000
# max            4.900000  10934.000000

# %% [markdown]
# The 'Average Cost for two' and 'Votes' columns are right-skewed, while the 'Longitude', 'Latitude', 'Price range', and 'Aggregate rating' columns are left-skewed. High standard deviations and differences between the 75th percentile and maximum values in 'Longitude', 'Latitude', 'Average Cost for two', and 'Votes' indicate significant spread and outliers.
#
# India, especially New Delhi, has the most Zomato listings, with Cafe Coffee Day having the highest number of outlets. North-Indian cuisine is the most common, with Connaught Place in New Delhi being the top locality. Most Zomato patrons prefer table bookings over online delivery. The 'Switch to order menu' column has no variability and can be dropped.

# %%
# Checking the table booking

zomato[zomato["Has Table booking"]=="Yes"].groupby("Country").size()
# Out:
# Country
# India             1111
# Phillipines         14
# Qatar                1
# South Africa         2
# UAE                 18
# United Kingdom      12
# dtype: int64

# %% [markdown]
# Zomato has Table booking system in India, Phillipines, Qatar,South Africa,UAE and United Kingdom only.

# %%
# Checking the Online delivery .

zomato[zomato["Has Online delivery"]=="Yes"].groupby("Country").size()
# Out:
# Country
# India    2423
# UAE        28
# dtype: int64

# %% [markdown]
# - Zomato has online delivery system with only India and UAE.

# %%
#Extracting the country who gave the most no. of zero rating 

zero_rating=zomato[zomato["Aggregate rating"]==0].groupby("Country").size().sort_values(ascending=False).reset_index().rename(columns={0:"Count"})
zero_rating
# Out:
#           Country  Count
# 0           India   2139
# 1          Brazil      5
# 2   United States      3
# 3  United Kingdom      1

# %% [markdown]
# Majority of zero was rated by Indian citizens .

# %%
# Lets find out the Country wise currency

zomato.groupby(["Currency","Country"]).size().reset_index()
# Out:
#                   Currency         Country     0
# 0         Botswana Pula(P)     Phillipines    22
# 1       Brazilian Real(R$)          Brazil    60
# 2                Dollar($)       Australia    24
# 3                Dollar($)          Canada     4
# 4                Dollar($)       Singapore    20
# 5                Dollar($)   United States   425
# 6       Emirati Diram(AED)             UAE    60
# 7       Indian Rupees(Rs.)           India  8652
# 8   Indonesian Rupiah(IDR)       Indonesia    21
# 9            NewZealand($)     New Zealand    40
# 10              Pounds(£)  United Kingdom    80
# 11         Qatari Rial(QR)           Qatar    20
# 12                 Rand(R)    South Africa    60
# 13   Sri Lankan Rupee(LKR)       Sri Lanka    20
# 14        Turkish Lira(TL)          Turkey    34

# %%
zomato[["Currency","Country"]].groupby(["Currency","Country"]).count().reset_index()
# Out:
#                   Currency         Country
# 0         Botswana Pula(P)     Phillipines
# 1       Brazilian Real(R$)          Brazil
# 2                Dollar($)       Australia
# 3                Dollar($)          Canada
# 4                Dollar($)       Singapore
# 5                Dollar($)   United States
# 6       Emirati Diram(AED)             UAE
# 7       Indian Rupees(Rs.)           India
# 8   Indonesian Rupiah(IDR)       Indonesia
# 9            NewZealand($)     New Zealand
# 10              Pounds(£)  United Kingdom
# 11         Qatari Rial(QR)           Qatar
# 12                 Rand(R)    South Africa
# 13   Sri Lankan Rupee(LKR)       Sri Lanka
# 14        Turkish Lira(TL)          Turkey

# %% [markdown]
# # Data Visualisation

# %%
plt.figure(figsize=(30,30))
sns.set(font_scale=2)
p=1
for i in cat_col[5:]:
    if p<=5:
        ax=plt.subplot(3,2,p)
        sns.countplot(x=zomato[i],palette='CMRmap')
        plt.xticks(rotation=90)
        p+=1
plt.tight_layout()

# %%
p=1
plt.figure(figsize=(15,6))
sns.set(font_scale=1)
for i in num_col[1:]:
    if p<=3:
        ax=plt.subplot(1,3,p)
        sns.regplot(x='Average Cost for two',y=zomato[i],scatter_kws=dict(color='r'),line_kws=dict(color='k'),data=zomato)
        plt.xticks(rotation=90)
        p+=1
plt.tight_layout()

# %%
plt.figure(figsize=(10,5))
ab = sns.countplot(x =zomato['Price range'],palette='Set2',linewidth=2,edgecolor='black')
plt.ylabel('Count',fontsize=15)
plt.xlabel('Price range',fontsize=15)

for i in ab.containers:
    ab.bar_label(i,fontsize=12)
plt.show()

# %%
# Visualizing the feature 'Currency' in countplot

plt.figure(figsize=(15,5))
ab = sns.countplot(x =zomato['Currency'],palette='Set2')
plt.ylabel('Count',fontsize=15)
plt.xlabel('Currency',fontsize=15)
plt.xticks(fontsize=12,rotation=90)

for i in ab.containers:
    ab.bar_label(i,fontsize=12)
plt.show()

# %%
# Visualizing the feature 'Aggregate rating' in countplot

plt.figure(figsize=(18,6))
ab = sns.countplot(x= zomato['Aggregate rating'],palette='Set2',linewidth=2,edgecolor='black')
plt.ylabel('Count',fontsize=15)
plt.xlabel('Aggregate rating',fontsize=15)

for i in ab.containers:
    ab.bar_label(i,fontsize=11)
plt.show()

# %%
plotnumber = 1
plt.figure(figsize=(20,18))

for i in num_col:
    if plotnumber<=16:
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(zomato[i],bins =6,kde=True)
        plt.xlabel(i,fontsize=16)
        plotnumber+=1
plt.show()

# %%
sns.catplot(y='Average Cost for two',x='Rating text',data=zomato,kind='bar')

# %%
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
fig,axes = plt.subplots(2, 2, figsize=(24,15))
fig.suptitle('Price range according to different Parameters',fontsize=30) 
sns.countplot(ax=axes[0, 0],x='Has Online delivery',hue='Price range',data=zomato,palette="Set2") 
sns.ecdfplot(ax=axes[0, 1],x='Aggregate rating',hue='Price range', data=zomato,palette="Dark2",stat='count')
sns.histplot(ax=axes[1, 0],x='Rating text',hue='Price range',data=zomato,palette="gnuplot",multiple='stack')
sns.boxplot(ax=axes[1, 1],x='Country',y='Price range',data=zomato,palette="spring")
plt.xticks(rotation=90)
plt.show()

# %%
# Visualizing the feature 'Rating text' in countplot

plt.figure(figsize=(10,6))
ab = sns.countplot(x =zomato['Rating text'],palette='Set1',linewidth=2,edgecolor='black')
plt.xlabel('Rating text',fontsize=15)
plt.ylabel('Count',fontsize=15)

for i in ab.containers:
    ab.bar_label(i,fontsize=12)
plt.show()

# %%
cols = ['Price range','Is delivering now','Has Online delivery','Has Table booking']
for i in cols:
    sns.catplot(x= i,y='Average Cost for two',data=zomato,kind='bar')

# %%
sns.barplot(x="Price range", y='Aggregate rating', hue='Has Table booking', data=zomato)
# Out:
# <Axes: xlabel='Price range', ylabel='Aggregate rating'>

# %%
sns.barplot(x="Price range", y='Aggregate rating', hue='Is delivering now', data=zomato)
# Out:
# <Axes: xlabel='Price range', ylabel='Aggregate rating'>

# %%
# Visualizing the Has Table booking Vs Aggregate rating by barplot

plt.figure(figsize=(8,5))
cat=sns.barplot(data=zomato, x='Has Table booking',y='Aggregate rating',palette='husl')
plt.xlabel("Has Table booking",fontsize=15)
plt.ylabel("Aggregate rating",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
for i in cat.containers:
    cat.bar_label(i,fontsize=12)
plt.show()

# %%
# Visualizing the Price range Vs Aggregate rating by barplot

plt.figure(figsize=(8,5))
cat=sns.barplot(data=zomato, x='Price range',y='Aggregate rating',palette='husl')

plt.xlabel("Price range",fontsize=15)
plt.ylabel("Aggregate rating",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

for i in cat.containers:
    cat.bar_label(i,fontsize=12)
plt.show()

# %%
# Visualizing Rating text Vs Average Cost for two Vs Price range in India by barplot


filter = zomato[zomato['Country']=='India']
plt.figure(figsize=(15,8))
cat=sns.barplot(data=filter, x='Rating text',y='Average Cost for two',hue='Price range',palette='viridis')
plt.xlabel("Rating text",fontsize=15)
plt.ylabel("Average Cost for two",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Rating text Vs Average Cost for two Vs Price range in India',fontsize=15)

for i in cat.containers:
    cat.bar_label(i,fontsize=10,padding=20,rotation=60)
plt.show()

# %%
# Visualizing the Has Online delivery Vs Aggregate rating by barplot

plt.figure(figsize=(8,5))
cat=sns.barplot(data=zomato, x='Has Online delivery',y='Aggregate rating',palette='husl')

plt.xlabel("Has Online delivery",fontsize=15)
plt.ylabel("Aggregate rating",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

for i in cat.containers:
    cat.bar_label(i,fontsize=12)
plt.show()

# %%
# Visualizing Rating text Vs Average Cost for two Vs Price range in United States by barplot

filter = zomato[zomato['Country']=='United States']
plt.figure(figsize=(12,8))
cat=sns.barplot(data=filter, x='Rating text',y='Average Cost for two',hue='Price range',palette='viridis')

plt.xlabel("Rating text",fontsize=15)
plt.ylabel("Average Cost for two",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Rating text Vs Average Cost for two Vs Price range in United States',fontsize=15)

for i in cat.containers:
    cat.bar_label(i,fontsize=12,padding=10,rotation=60)
plt.show()

# %%
# Visualizing Rating text Vs Average Cost for two Vs Price range in UAE by barplot

filter = zomato[zomato['Country']=='UAE']
plt.figure(figsize=(8,8))
cat=sns.barplot(data=filter, x='Rating text',y='Average Cost for two',hue='Price range',palette='magma')
plt.xlabel("Rating text",fontsize=15)
plt.ylabel("Average Cost for two",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Rating text Vs Average Cost for two Vs Price range in UAE',fontsize=15)

for i in cat.containers:
    cat.bar_label(i,fontsize=12,padding=3)
plt.show()

# %%
# Visualizing Rating text Vs Average Cost for two Vs Price range in United Kingdom by barplot


filter = zomato[zomato['Country']=='United Kingdom']
plt.figure(figsize=(8,8))
cat=sns.barplot(data=filter, x='Rating text',y='Average Cost for two',hue='Price range',palette='viridis')

plt.xlabel("Rating text",fontsize=15)
plt.ylabel("Average Cost for two",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Rating text Vs Average Cost for two Vs Price range in United Kingdom',fontsize=15)

for i in cat.containers:
    cat.bar_label(i,fontsize=10,padding=5)
plt.show()

# %%
# Visualizing Rating text Vs Average Cost for two Vs Price range in South Africa by barplot


filter = zomato[zomato['Country']=='South Africa']
plt.figure(figsize=(8,8))
cat=sns.barplot(data=filter, x='Rating text',y='Average Cost for two',hue='Price range',palette='magma')
plt.xlabel("Rating text",fontsize=15)
plt.ylabel("Average Cost for two",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Rating text Vs Average Cost for two Vs Price range in South Africa',fontsize=15)

for i in cat.containers:
    cat.bar_label(i,fontsize=10,padding=2)
plt.show()

# %%
# Visualizing Rating text Vs Average Cost for two Vs Price range in Brazil by barplot


filter = zomato[zomato['Country']=='Brazil']
plt.figure(figsize=(8,8))
cat=sns.barplot(data=filter, x='Rating text',y='Average Cost for two',hue='Price range',palette='viridis')

plt.xlabel("Rating text",fontsize=15)
plt.ylabel("Average Cost for two",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Rating text Vs Average Cost for two Vs Price range in Brazil',fontsize=15)

for i in cat.containers:
    cat.bar_label(i,fontsize=10,padding=3)
plt.show()

# %%
# Visualizing Rating text Vs Average Cost for two Vs Price range in Australia by barplot


filter = zomato[zomato['Country']=='Australia']
plt.figure(figsize=(8,8))
cat=sns.barplot(data=filter, x='Rating text',y='Average Cost for two',hue='Price range',palette='hls')
plt.xlabel("Rating text",fontsize=15)
plt.ylabel("Average Cost for two",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Rating text Vs Average Cost for two Vs Price range in Australia',fontsize=15)

for i in cat.containers:
    cat.bar_label(i,fontsize=10,padding=3)
plt.show()

# %%
# Visualizing Average Cost for two Vs City in India by barplot

filter = zomato[zomato['Country']=='India']
plt.figure(figsize=(10,8))
cat=sns.barplot(data=filter, x='City',y='Average Cost for two',palette='hls')
plt.xlabel("City",fontsize=15)
plt.ylabel("Average Cost for two",fontsize=15)
plt.xticks(fontsize=12,rotation=90)
plt.yticks(fontsize=12)
plt.title('Rating text Vs Average Cost for two Vs Price range in India',fontsize=15)
for i in cat.containers:
    cat.bar_label(i,fontsize=10,padding=2,rotation=30)
plt.show()

# %%
# Visualizing the dataset with Boxplot to check outliers

plt.figure(figsize=(20,15))
st = 1
for i in num_col:
    if st <=6:
        sub = plt.subplot(3,2,st)
        sns.boxplot(zomato[i],color='#76cd26')
        plt.xlabel(i,fontsize=18)
        plt.xticks(fontsize=15)
    st+=1
plt.tight_layout()

# %% [markdown]
# outliers are present in the dataset

# %% [markdown]
# # LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for i in zomato.columns:
    if (zomato[i].dtypes == 'object'):
        zomato[i] = le.fit_transform(zomato[i].values.reshape(-1,1))
zomato.head(5)
# Out:
#    Country  Restaurant Name  City  Locality Verbose  Longitude   Latitude  \
# 0        3             3196     1                17  78.011544  27.161661
# 1        3             5253     1                17   0.000000   0.000000
# 2        3             6911     1                17  78.011608  27.160832
# 3        3             1637     1               205  77.998092  27.195928
# 4        3             4914     1               205  78.007553  27.201725
#
#    Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0      1514                   850         4                  0
# 1      1514                   700         4                  0
# 2      1306                   500         4                  0
# 3      1645                   400         4                  0
# 4      1373                  1000         4                  0
#
#    Has Online delivery  Is delivering now  Price range  Aggregate rating  \
# 0                    0                  0            3               3.9
# 1                    0                  0            2               3.5
# 2                    0                  0            2               3.6
# 3                    0                  0            2               4.0
# 4                    0                  0            3               4.2
#
#    Rating text  Votes
# 0            2    140
# 1            2     71
# 2            2     94
# 3            5     87
# 4            5    177

# %%
zomato.describe()
# Out:
#            Country  Restaurant Name         City  Locality Verbose  \
# count  9542.000000      9542.000000  9542.000000       9542.000000
# mean      3.727101      3648.654265    77.570530        676.259694
# std       2.634405      2140.178731    22.781307        330.752100
# min       0.000000         0.000000     0.000000          0.000000
# 25%       3.000000      1775.250000    78.250000        387.000000
# 50%       3.000000      3590.500000    87.000000        705.000000
# 75%       3.000000      5478.750000    87.000000        951.000000
# max      14.000000      7436.000000   139.000000       1262.000000
#
#          Longitude     Latitude     Cuisines  Average Cost for two  \
# count  9542.000000  9542.000000  9542.000000           9542.000000
# mean     64.274997    25.848532   989.163173           1200.326137
# std      41.197602    11.010094   514.326600          16128.743876
# min    -157.948486   -41.330428     0.000000              0.000000
# 25%      77.081565    28.478658   497.000000            250.000000
# 50%      77.192031    28.570444  1126.000000            400.000000
# 75%      77.282043    28.642711  1354.000000            700.000000
# max     174.832089    55.976980  1824.000000         800000.000000
#
#           Currency  Has Table booking  Has Online delivery  Is delivering now  \
# count  9542.000000        9542.000000          9542.000000        9542.000000
# mean      3.979564           0.121358             0.256864           0.003563
# std       0.912652           0.326560             0.436927           0.059589
# min       0.000000           0.000000             0.000000           0.000000
# 25%       4.000000           0.000000             0.000000           0.000000
# 50%       4.000000           0.000000             0.000000           0.000000
# 75%       4.000000           0.000000             1.000000           0.000000
# max      11.000000           1.000000             1.000000           1.000000
#
#        Price range  Aggregate rating  Rating text         Votes
# count  9542.000000       9542.000000  9542.000000   9542.000000
# mean      1.804968          2.665238     1.788933    156.772060
# std       0.905563          1.516588     1.694795    430.203324
# min       1.000000          0.000000     0.000000      0.000000
# 25%       1.000000          2.500000     0.000000      5.000000
# 50%       2.000000          3.200000     2.000000     31.000000
# 75%       2.000000          3.700000     3.000000    130.000000
# max       4.000000          4.900000     5.000000  10934.000000

# %% [markdown]
# # Check Correlation of Dataset After Label Encoding

# %%
zomato.corr()
# Out:
#                        Country  Restaurant Name      City  Locality Verbose  \
# Country               1.000000         0.018191 -0.177879         -0.115510
# Restaurant Name       0.018191         1.000000 -0.001969          0.003915
# City                 -0.177879        -0.001969  1.000000          0.091571
# Locality Verbose     -0.115510         0.003915  0.091571          1.000000
# Longitude            -0.763055        -0.002419  0.114510          0.083185
# Latitude              0.180572         0.010054 -0.004607         -0.020678
# Cuisines             -0.131155         0.051729  0.026584          0.006213
# Average Cost for two -0.003793         0.019235 -0.028306         -0.011882
# Currency             -0.098312         0.009415 -0.074380          0.022008
# Has Table booking    -0.061157         0.041148 -0.004039         -0.065307
# Has Online delivery  -0.139329         0.028024  0.011926         -0.032044
# Is delivering now    -0.016506         0.011992 -0.014005         -0.007391
# Price range           0.179961         0.061676 -0.104848         -0.112868
# Aggregate rating      0.254590         0.029483 -0.130848         -0.173171
# Rating text           0.205885         0.012139 -0.099135         -0.036226
# Votes                 0.155082         0.018523 -0.078513         -0.123503
#
#                       Longitude  Latitude  Cuisines  Average Cost for two  \
# Country               -0.763055  0.180572 -0.131155             -0.003793
# Restaurant Name       -0.002419  0.010054  0.051729              0.019235
# City                   0.114510 -0.004607  0.026584             -0.028306
# Locality Verbose       0.083185 -0.020678  0.006213             -0.011882
# Longitude              1.000000  0.045415  0.129325              0.045948
# Latitude               0.045415  1.000000  0.037841             -0.111080
# Cuisines               0.129325  0.037841  1.000000              0.005875
# Average Cost for two   0.045948 -0.111080  0.005875              1.000000
# Currency               0.332637 -0.100965  0.070336              0.045566
# Has Table booking      0.099860  0.054874  0.050867              0.007733
# Has Online delivery    0.177922  0.119087 -0.016303             -0.019017
# Is delivering now      0.018703  0.015037  0.007809             -0.001866
# Price range           -0.080257 -0.166735 -0.005265              0.075111
# Aggregate rating      -0.114733  0.000197 -0.080832              0.051864
# Rating text           -0.183417 -0.129332 -0.079944              0.031440
# Votes                 -0.084371 -0.022914 -0.032935              0.067833
#
#                       Currency  Has Table booking  Has Online delivery  \
# Country              -0.098312          -0.061157            -0.139329
# Restaurant Name       0.009415           0.041148             0.028024
# City                 -0.074380          -0.004039             0.011926
# Locality Verbose      0.022008          -0.065307            -0.032044
# Longitude             0.332637           0.099860             0.177922
# Latitude             -0.100965           0.054874             0.119087
# Cuisines              0.070336           0.050867            -0.016303
# Average Cost for two  0.045566           0.007733            -0.019017
# Currency              1.000000          -0.000118             0.005806
# Has Table booking    -0.000118           1.000000             0.101041
# Has Online delivery   0.005806           0.101041             1.000000
# Is delivering now     0.001339          -0.016838             0.101713
# Price range           0.075073           0.502166             0.077887
# Aggregate rating     -0.005337           0.190351             0.226250
# Rating text           0.014355           0.044014            -0.081057
# Votes                -0.026488           0.169619             0.074532
#
#                       Is delivering now  Price range  Aggregate rating  \
# Country                       -0.016506     0.179961          0.254590
# Restaurant Name                0.011992     0.061676          0.029483
# City                          -0.014005    -0.104848         -0.130848
# Locality Verbose              -0.007391    -0.112868         -0.173171
# Longitude                      0.018703    -0.080257         -0.114733
# Latitude                       0.015037    -0.166735          0.000197
# Cuisines                       0.007809    -0.005265         -0.080832
# Average Cost for two          -0.001866     0.075111          0.051864
# Currency                       0.001339     0.075073         -0.005337
# Has Table booking             -0.016838     0.502166          0.190351
# Has Online delivery            0.101713     0.077887          0.226250
# Is delivering now              1.000000     0.010937          0.019231
# Price range                    0.010937     1.000000          0.438356
# Aggregate rating               0.019231     0.438356          1.000000
# Rating text                   -0.031989     0.163778         -0.182835
# Votes                         -0.001105     0.309474          0.313474
#
#                       Rating text     Votes
# Country                  0.205885  0.155082
# Restaurant Name          0.012139  0.018523
# City                    -0.099135 -0.078513
# Locality Verbose        -0.036226 -0.123503
# Longitude               -0.183417 -0.084371
# Latitude                -0.129332 -0.022914
# Cuisines                -0.079944 -0.032935
# Average Cost for two     0.031440  0.067833
# Currency                 0.014355 -0.026488
# Has Table booking        0.044014  0.169619
# Has Online delivery     -0.081057  0.074532
# Is delivering now       -0.031989 -0.001105
# Price range              0.163778  0.309474
# Aggregate rating        -0.182835  0.313474
# Rating text              1.000000  0.203622
# Votes                    0.203622  1.000000

# %%
# Visualizing correlation of the dataset in heatmap

plt.figure(figsize=(25,20))
sns.heatmap(zomato.corr(),annot=True,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# The column 'Longitude' columns are negatively correlated with target variable whereas col 'Aggregate rating','Votes' and 'Price Range' columns are positively correlated with each other.

# %%
zomato.corr()['Price range'].sort_values(ascending=False)
# Out:
# Price range             1.000000
# Has Table booking       0.502166
# Aggregate rating        0.438356
# Votes                   0.309474
# Country                 0.179961
# Rating text             0.163778
# Has Online delivery     0.077887
# Average Cost for two    0.075111
# Currency                0.075073
# Restaurant Name         0.061676
# Is delivering now       0.010937
# Cuisines               -0.005265
# Longitude              -0.080257
# City                   -0.104848
# Locality Verbose       -0.112868
# Latitude               -0.166735
# Name: Price range, dtype: float64

# %%
# Visualizing the correlation of the features with target variable price range

plt.figure(figsize=(10,6))
zomato.corr()['Price range'].sort_values(ascending=False).plot(kind='bar',color='#de0c62')
plt.xlabel('Feature',fontsize=20)
plt.ylabel('Target',fontsize=20)
plt.title('Correlation',fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
zomato.corr()['Average Cost for two'].sort_values(ascending=False)
# Out:
# Average Cost for two    1.000000
# Price range             0.075111
# Votes                   0.067833
# Aggregate rating        0.051864
# Longitude               0.045948
# Currency                0.045566
# Rating text             0.031440
# Restaurant Name         0.019235
# Has Table booking       0.007733
# Cuisines                0.005875
# Is delivering now      -0.001866
# Country                -0.003793
# Locality Verbose       -0.011882
# Has Online delivery    -0.019017
# City                   -0.028306
# Latitude               -0.111080
# Name: Average Cost for two, dtype: float64

# %%
# Visualizing the correlation of the features with target variable 'Average Cost for two'

plt.figure(figsize=(10,6))
zomato.corr()['Average Cost for two'].sort_values(ascending=False).plot(kind='bar',color='#de0c62')
plt.xlabel('Feature',fontsize=20)
plt.ylabel('Target',fontsize=20)
plt.title('Correlation',fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The column 'Cuisines, Has Table booking, Restaurant Name, Rating text, Currency, Longitude, Aggregate rating, Votes and Price range are positively correlated with target variable
# The column 'Latitude', City, Has Online delivery, Locality Verbose, Country and Is delivering now are negatively correlated with target variable'Average Cost for Two'.

# %% [markdown]
# # Removing outliers

# %%
from scipy.stats import zscore

col =['Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

z1=zomato[col]
z1.head(5)
# Out:
#    Longitude   Latitude  Average Cost for two  Price range  Aggregate rating  \
# 0  78.011544  27.161661                   850            3               3.9
# 1   0.000000   0.000000                   700            2               3.5
# 2  78.011608  27.160832                   500            2               3.6
# 3  77.998092  27.195928                   400            2               4.0
# 4  78.007553  27.201725                  1000            3               4.2
#
#    Votes
# 0    140
# 1     71
# 2     94
# 3     87
# 4    177

# %%
z = np.abs(zscore(z1))
threshold=3

# %%
zomato_new = zomato[(z<3).all(axis=1)]

# %%
zomato.shape
# Out:
# (9542, 16)

# %%
zomato_new.shape
# Out:
# (8756, 16)

# %%
# Data Loss

data_loss =  (zomato.shape[0]-zomato_new.shape[0])/zomato.shape[0]*100
print('loss of data in % :',data_loss)
# Out:
# loss of data in % : 8.237266820373087

# %% [markdown]
# # Checking and removing skewness

# %%
# Checking skewness
zomato_new.skew().sort_values(ascending=False)[np.abs(zomato_new.skew())>0.5]
# Out:
# Is delivering now       15.956834
# Currency                 6.610471
# Country                  6.224507
# Average Cost for two     3.667387
# Votes                    3.555810
# Has Table booking        2.268965
# Has Online delivery      1.016921
# Price range              0.987956
# Aggregate rating        -0.887535
# City                    -1.505859
# Latitude                -2.246169
# Longitude               -3.179687
# dtype: float64

# %%
# Removing skewness using power transform 

from sklearn.preprocessing import PowerTransformer 

skew =['Longitude','Price range','Aggregate rating','Votes','Latitude']


pt = PowerTransformer(method='yeo-johnson',standardize=False)
zomato_new[skew] = pt.fit_transform(zomato_new[skew].values)

# %%
zomato_new.skew().sort_values(ascending=False)
# Out:
# Is delivering now       15.956834
# Currency                 6.610471
# Country                  6.224507
# Average Cost for two     3.667387
# Has Table booking        2.268965
# Has Online delivery      1.016921
# Rating text              0.438078
# Latitude                 0.409584
# Price range              0.222590
# Restaurant Name          0.042649
# Votes                   -0.012360
# Locality Verbose        -0.230693
# Cuisines                -0.343326
# Aggregate rating        -0.620066
# Longitude               -0.963748
# City                    -1.505859
# dtype: float64

# %%
# Dropping the feature Is delivering now

zomato_new.drop(['Is delivering now'],axis=1,inplace=True)

# %%
# Applying sqrt transformation method to the feature Average Cost for two

zomato_new['Average Cost for two']= np.sqrt(zomato_new['Average Cost for two'])

# %%
# Checking skewness

zomato_new.skew()
# Out:
# Country                 6.224507
# Restaurant Name         0.042649
# City                   -1.505859
# Locality Verbose       -0.230693
# Longitude              -0.963748
# Latitude                0.409584
# Cuisines               -0.343326
# Average Cost for two    1.546098
# Currency                6.610471
# Has Table booking       2.268965
# Has Online delivery     1.016921
# Price range             0.222590
# Aggregate rating       -0.620066
# Rating text             0.438078
# Votes                  -0.012360
# dtype: float64

# %% [markdown]
# # Splitting the dataset

# %%
x = zomato_new.drop('Average Cost for two',axis=1)
x.head(5)
# Out:
#    Country  Restaurant Name  City  Locality Verbose    Longitude    Latitude  \
# 0        3             3196     1                17  8540.395496  183.395240
# 1        3             5253     1                17     0.000000    0.000000
# 2        3             6911     1                17  8540.411004  183.385898
# 3        3             1637     1               205  8537.112079  183.781731
# 4        3             4914     1               205  8539.421179  183.847151
#
#    Cuisines  Currency  Has Table booking  Has Online delivery  Price range  \
# 0      1514         4                  0                    0     0.606284
# 1      1514         4                  0                    0     0.556571
# 2      1306         4                  0                    0     0.556571
# 3      1645         4                  0                    0     0.556571
# 4      1373         4                  0                    0     0.606284
#
#    Aggregate rating  Rating text     Votes
# 0          8.151739            2  5.201439
# 1          6.975607            2  4.464518
# 2          7.263085            2  4.767270
# 3          8.456605            5  4.683510
# 4          9.079150            5  5.459257

# %%
# Splitting the target variable for train, test

y = zomato_new['Average Cost for two']
y.shape
# Out:
# (8756,)

# %% [markdown]
# # Scaling the data using standardscaler

# %%
# Applying Scaling method

from sklearn.preprocessing import StandardScaler

m = ['Price range','Aggregate rating','Votes','Longitude','Latitude','City']

st= StandardScaler()
x[m] = st.fit_transform(x[m].values)
x.sample(5)
# Out:
#       Country  Restaurant Name      City  Locality Verbose  Longitude  \
# 8536        3             6689  1.327488               516  -0.099731
# 3874        3             2879  0.431294               517   0.226336
# 5253        3             1099  0.431294               719   0.220551
# 8244        3             2967  0.481083               999   0.242383
# 1011        3             1200 -1.410882               747   0.215115
#
#       Latitude  Cuisines  Currency  Has Table booking  Has Online delivery  \
# 8536 -1.373060       907         4                  1                    0
# 3874  0.222759       982         4                  0                    1
# 5253  0.225281       331         4                  0                    0
# 8244  0.210735       497         4                  0                    0
# 1011  0.181612      1101         4                  0                    1
#
#       Price range  Aggregate rating  Rating text     Votes
# 8536     1.355853          1.197813            5  2.095921
# 3874    -0.977182          0.810173            2 -0.055815
# 5253    -0.977182          0.624695            2  0.407047
# 8244    -0.977182          0.102529            0 -0.787291
# 1011     1.355853          0.905011            2  0.774375

# %% [markdown]
# # Checking multicollinearity using Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def vif(x):
    vif = pd.DataFrame()
    vif['Column Name'] = x.columns
    vif['VIF Factor'] = [variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif.sort_values(by ='VIF Factor', ascending = False))
vif(x)
# Out:
#             Column Name  VIF Factor
# 7              Currency   21.665653
# 0               Country   11.993688
# 3      Locality Verbose    5.313225
# 13                Votes    4.882037
# 6              Cuisines    4.875512
# 11     Aggregate rating    4.469214
# 1       Restaurant Name    3.829212
# 12          Rating text    2.489680
# 10          Price range    1.758918
# 9   Has Online delivery    1.593648
# 8     Has Table booking    1.529522
# 5              Latitude    1.370343
# 4             Longitude    1.324380
# 2                  City    1.067281

# %%
# Dropping the feature Currency

x1=x.drop(['Currency'],axis=1)

# %%
vif(x1)
# Out:
#             Column Name  VIF Factor
# 0               Country    6.737280
# 12                Votes    4.878495
# 3      Locality Verbose    4.501184
# 10     Aggregate rating    4.461388
# 6              Cuisines    4.145940
# 1       Restaurant Name    3.583541
# 11          Rating text    2.431886
# 9           Price range    1.724301
# 8   Has Online delivery    1.552047
# 7     Has Table booking    1.521513
# 5              Latitude    1.362779
# 4             Longitude    1.324367
# 2                  City    1.066865

# %%
x = x1.copy()

# %%
x.shape
# Out:
# (8756, 13)

# %% [markdown]
# # building Ml model

# %%
# Importing required libraries

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from xgboost import XGBRegressor
import pickle
from sklearn import metrics
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import cross_val_score

# %%
def random_st_reg(model):
    max_score = 0
    max_rs = 0
    print('\n',model)
    for i in range(1,50):
        x_train, x_test,y_train,y_test= train_test_split(x,y,test_size = 0.20, random_state = i)
        model.fit(x_train,y_train)
        pred_test = model.predict(x_test)
        score = r2_score(y_test,pred_test)
        if score > max_score:
            max_score = score
            max_rs = i
    print("At random state ", max_rs, 'the model is having accuracy score of ', max_score)
    return max_rs

# %%
def model_fit_reg(model, rs):
    x_train, x_test,y_train,y_test= train_test_split(x,y,test_size = 0.20, random_state = rs)
    model.fit(x_train,y_train)
    pred_test = model.predict(x_test)
    r2 = r2_score(y_test,pred_test)
    mse = mean_squared_error(y_test,pred_test)
    mae = mean_absolute_error(y_test,pred_test)
    cv_score = cross_val_score(model,x,y, cv = 8)
    cv_mean = cv_score.mean()
    print("\n R2 score is ", r2)
    print("-"*50)
    print("Mean Sqaured Error is ",mse)
    print("-"*50)
    print("Mean Absolute Error is ",mae)
    print("-"*50)
    print("The cv score is ", cv_mean, "and the R2 score  is ",r2)
    print(f'\n Difference between accuracy score and cross val score {(r2-cv_mean)*100:.2f}')
    print("-"*50)

# %%
def model_reg(m):
    m_rs = random_st_reg(m)
    model_fit_reg(m,m_rs)

# %%
models = [LinearRegression(), KNeighborsRegressor(), SVR(), DecisionTreeRegressor(), RandomForestRegressor(n_estimators=100), AdaBoostRegressor(),GradientBoostingRegressor(), ExtraTreesRegressor(), XGBRegressor()]

# %%
for i in models:
    model_reg(i)
# Out:
#  LinearRegression()
# At random state  22 the model is having accuracy score of  0.7699535201312315
#
#  R2 score is  0.7699535201312315
# --------------------------------------------------
# Mean Sqaured Error is  19.839551761711075
# --------------------------------------------------
# Mean Absolute Error is  3.1912991308003256
# --------------------------------------------------
# The cv score is  0.5485493207514025 and the R2 score  is  0.7699535201312315
#
#  Difference between accuracy score and cross val score 22.14
# --------------------------------------------------
#
#  KNeighborsRegressor()
# At random state  3 the model is having accuracy score of  0.0722711182101674
#
#  R2 score is  0.0722711182101674
# --------------------------------------------------
# Mean Sqaured Error is  81.38506437368399
# --------------------------------------------------
# Mean Absolute Error is  6.240953694287826
# --------------------------------------------------
# The cv score is  -0.09770003693712392 and the R2 score  is  0.0722711182101674
#
#  Difference between accuracy score and cross val score 17.00
# --------------------------------------------------
#
#  SVR()
# At random state  39 the model is having accuracy score of  0.00411342498751921
#
#  R2 score is  0.00411342498751921
# --------------------------------------------------
# Mean Sqaured Error is  85.27873605572202
# --------------------------------------------------
# Mean Absolute Error is  6.445866747798624
# --------------------------------------------------
# The cv score is  -0.059700728684537324 and the R2 score  is  0.00411342498751921
#
#  Difference between accuracy score and cross val score 6.38
# --------------------------------------------------
#
#  DecisionTreeRegressor()
# At random state  13 the model is having accuracy score of  0.8369374264104794
#
#  R2 score is  0.8321347700893307
# --------------------------------------------------
# Mean Sqaured Error is  15.686341815281578
# --------------------------------------------------
# Mean Absolute Error is  2.651346870502093
# --------------------------------------------------
# The cv score is  0.562202908627681 and the R2 score  is  0.8321347700893307
#
#  Difference between accuracy score and cross val score 26.99
# --------------------------------------------------
#
#  RandomForestRegressor()
# At random state  40 the model is having accuracy score of  0.9092706515436852
#
#  R2 score is  0.908000557339608
# --------------------------------------------------
# Mean Sqaured Error is  8.44123770956345
# --------------------------------------------------
# Mean Absolute Error is  2.0874721167819064
# --------------------------------------------------
# The cv score is  0.6935438682909866 and the R2 score  is  0.908000557339608
#
#  Difference between accuracy score and cross val score 21.45
# --------------------------------------------------
#
#  AdaBoostRegressor()
# At random state  3 the model is having accuracy score of  0.8625101296232888
#
#  R2 score is  0.8561663887461842
# --------------------------------------------------
# Mean Sqaured Error is  12.617811022987087
# --------------------------------------------------
# Mean Absolute Error is  2.799431092250542
# --------------------------------------------------
# The cv score is  0.5997051785698477 and the R2 score  is  0.8561663887461842
#
#  Difference between accuracy score and cross val score 25.65
# --------------------------------------------------
#
#  GradientBoostingRegressor()
# At random state  3 the model is having accuracy score of  0.9038200824026182
#
#  R2 score is  0.9041338421283263
# --------------------------------------------------
# Mean Sqaured Error is  8.409863681932244
# --------------------------------------------------
# Mean Absolute Error is  2.2317640984965466
# --------------------------------------------------
# The cv score is  0.6890794717645291 and the R2 score  is  0.9041338421283263
#
#  Difference between accuracy score and cross val score 21.51
# --------------------------------------------------
#
#  ExtraTreesRegressor()
# At random state  17 the model is having accuracy score of  0.9054047415063792
#
#  R2 score is  0.9058844677330521
# --------------------------------------------------
# Mean Sqaured Error is  8.956054826883221
# --------------------------------------------------
# Mean Absolute Error is  2.188863397673428
# --------------------------------------------------
# The cv score is  0.702587231630272 and the R2 score  is  0.9058844677330521
#
#  Difference between accuracy score and cross val score 20.33
# --------------------------------------------------
#
#  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)
# At random state  28 the model is having accuracy score of  0.9083883621351602
#
#  R2 score is  0.9083883621351602
# --------------------------------------------------
# Mean Sqaured Error is  7.8204481107436905
# --------------------------------------------------
# Mean Absolute Error is  2.054961080203356
# --------------------------------------------------
# The cv score is  0.6869727097509231 and the R2 score  is  0.9083883621351602
#
#  Difference between accuracy score and cross val score 22.14
# --------------------------------------------------

# %% [markdown]
# ExtraTreesRegressor is the best model with 90 % accuracy

# %% [markdown]
# # HyperParameter Tuning

# %%
# Hyper Parameter Tuning for ExtraTreesRegressor

grid_params={'n_estimators':[100,150,200],'criterion':['squared_error','friedman_mse'],
             'min_samples_split':[2,4,5,6],'min_samples_leaf':[1,2],'max_depth':[50,100,120,150]}          
        
grid = GridSearchCV(ExtraTreesRegressor(),param_grid=grid_params,n_jobs=-1)

# %%
grid.fit(x,y)
# Out:
# GridSearchCV(estimator=ExtraTreesRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse'],
#                          'max_depth': [50, 100, 120, 150],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 4, 5, 6],
#                          'n_estimators': [100, 150, 200]})

# %%
grid.best_score_
# Out:
# 0.6835290736487956

# %%
grid.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_depth': 100,
#  'min_samples_leaf': 2,
#  'min_samples_split': 5,
#  'n_estimators': 200}

# %%
final_model_reg= ExtraTreesRegressor(n_estimators = 200,criterion = 'friedman_mse',max_depth = 100,max_features = 'sqrt',min_samples_leaf = 2,min_samples_split = 5)
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size = 0.20, random_state = 17)
final_model_reg.fit(x_train, y_train)
pred_reg= final_model_reg.predict(x_test)
print('R2 Score',r2_score(y_test,pred_reg))
print('Mean Squared Error',mean_squared_error(y_test,pred_reg))
print('Mean Absolute Error',mean_absolute_error(y_test,pred_reg))
cv_score = cross_val_score(final_model_reg,x,y)
cv_mean =cv_score.mean()
print('CV score is ', cv_mean)
# Out:
# R2 Score 0.8922867112892539
# Mean Squared Error 10.250020331831328
# Mean Absolute Error 2.362435980991135
# CV score is  0.680755163651393

# %%
import pickle

filename = 'zomato regression model.pkl'
pickle.dump(final_model_reg,open(filename,'wb'))

# %%
original = np.array(y_test)
predicted = np.array(final_model_reg.predict(x_test))

predrainfal = pd.DataFrame({'Original Price':original,'Predicted Price':predicted})
predrainfal.sample(20)
# Out:
#       Original Price  Predicted Price
# 76          7.745967        10.270898
# 623        24.494897        24.381265
# 1394       28.284271        29.361062
# 171        14.142136        16.354256
# 572        14.142136        16.898458
# 480        17.320508        17.360641
# 569        34.641016        37.790984
# 1344       31.622777        32.971345
# 701        22.360680        23.821824
# 758        20.000000        15.552959
# 1191       17.320508        16.208340
# 513        15.811388        15.518189
# 1043       18.708287        17.386574
# 404        31.622777        37.405121
# 320        26.457513        23.877488
# 1629       12.247449        17.445659
# 983        24.494897        24.634206
# 631        18.708287        16.282121
# 311        12.247449        15.564423
# 21         26.457513        23.276215

# %% [markdown]
# # Classification Model Evaluation - 'Price range'

# %%
from scipy.stats import zscore

col =['Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

z2=zomato[col]
z2.head(5)
# Out:
#    Longitude   Latitude  Average Cost for two  Price range  Aggregate rating  \
# 0  78.011544  27.161661                   850            3               3.9
# 1   0.000000   0.000000                   700            2               3.5
# 2  78.011608  27.160832                   500            2               3.6
# 3  77.998092  27.195928                   400            2               4.0
# 4  78.007553  27.201725                  1000            3               4.2
#
#    Votes
# 0    140
# 1     71
# 2     94
# 3     87
# 4    177

# %% [markdown]
# # Removing outliers

# %%
z = np.abs(zscore(z2))
threshold=3

# %%
zomato2 = zomato[(z<3).all(axis=1)]

# %%
zomato.shape
# Out:
# (9542, 16)

# %%
zomato2.shape
# Out:
# (8756, 16)

# %%
data_loss = (zomato.shape[0]-zomato2.shape[0])/zomato.shape[0]*100
print('loss of data in % :',data_loss)
# Out:
# loss of data in % : 8.237266820373087

# %%
# Correlation check with target variable

zomato2.corr()['Price range'].sort_values()
# Out:
# City                   -0.137010
# Locality Verbose       -0.114265
# Latitude               -0.017057
# Longitude              -0.012885
# Cuisines                0.009651
# Is delivering now       0.016481
# Restaurant Name         0.066837
# Currency                0.095212
# Has Online delivery     0.114600
# Rating text             0.120186
# Country                 0.238584
# Aggregate rating        0.420318
# Votes                   0.424234
# Has Table booking       0.555907
# Average Cost for two    0.762662
# Price range             1.000000
# Name: Price range, dtype: float64

# %% [markdown]
# Features City, Locality Verbose, Latitude, Longitude are negatively correlated with target variable 'Price range'
#
# Features Cuisines, Is delivering now, Restaurant Name, Currency, Has Online delivery, Rating text, Country, Aggregate rating, Votes, Has Table booking and Average Cost for two are positively correlated with the target variable

# %% [markdown]
# # Checking and removing skewness

# %%
zomato2.skew()
# Out:
# Country                  6.224507
# Restaurant Name          0.042649
# City                    -1.505859
# Locality Verbose        -0.230693
# Longitude               -3.179687
# Latitude                -2.246169
# Cuisines                -0.343326
# Average Cost for two     3.667387
# Currency                 6.610471
# Has Table booking        2.268965
# Has Online delivery      1.016921
# Is delivering now       15.956834
# Price range              0.987956
# Aggregate rating        -0.887535
# Rating text              0.438078
# Votes                    3.555810
# dtype: float64

# %%
# Removing skewness using power transform
from sklearn.preprocessing import PowerTransformer 

skew2 =['Longitude','Latitude','Average Cost for two','Aggregate rating','Votes']

pt = PowerTransformer(method='yeo-johnson',standardize=False)
zomato2[skew2] = pt.fit_transform(zomato2[skew2].values)

# %%
zomato2.skew()
# Out:
# Country                  6.224507
# Restaurant Name          0.042649
# City                    -1.505859
# Locality Verbose        -0.230693
# Longitude               -0.963748
# Latitude                 0.409584
# Cuisines                -0.343326
# Average Cost for two     0.053731
# Currency                 6.610471
# Has Table booking        2.268965
# Has Online delivery      1.016921
# Is delivering now       15.956834
# Price range              0.987956
# Aggregate rating        -0.620066
# Rating text              0.438078
# Votes                   -0.012360
# dtype: float64

# %%
# Dropping the feature Is delivering now

zomato2.drop(['Is delivering now'],axis=1,inplace=True)

# %%
zomato2.skew()
# Out:
# Country                 6.224507
# Restaurant Name         0.042649
# City                   -1.505859
# Locality Verbose       -0.230693
# Longitude              -0.963748
# Latitude                0.409584
# Cuisines               -0.343326
# Average Cost for two    0.053731
# Currency                6.610471
# Has Table booking       2.268965
# Has Online delivery     1.016921
# Price range             0.987956
# Aggregate rating       -0.620066
# Rating text             0.438078
# Votes                  -0.012360
# dtype: float64

# %% [markdown]
# # Splitting the dataset

# %%
x2 = zomato2.drop("Price range",axis=1)
x2.sample(5)
# Out:
#       Country  Restaurant Name  City  Locality Verbose    Longitude  \
# 5092        3             7318    87               705  8290.595960
# 6511        3              190    87              1022  8365.230282
# 2664        3             2953    87               284  8344.673842
# 5054        3             2057    87               705  8293.912077
# 6636        3             6016    87              1026  8333.614159
#
#         Latitude  Cuisines  Average Cost for two  Currency  Has Table booking  \
# 5092  200.064509      1235              7.039142         4                  0
# 6511  200.955461      1235              6.554504         4                  0
# 2664  201.046150       512              9.712498         4                  1
# 5054  199.800276      1275              8.269471         4                  0
# 6636  201.308361      1329              9.031664         4                  0
#
#       Has Online delivery  Aggregate rating  Rating text     Votes
# 5092                    0          0.000000            3  0.697965
# 6511                    0          0.000000            3  0.697965
# 2664                    0          6.413937            0  4.967305
# 5054                    0          0.000000            3  0.000000
# 6636                    0          6.413937            0  2.709806

# %%
y2 = zomato2['Price range']
y2.shape
# Out:
# (8756,)

# %% [markdown]
# # Scaling the data using standardscaler

# %%
# Applying Scaling method

from sklearn.preprocessing import StandardScaler

m2 = ['Longitude','Latitude','Average Cost for two','Aggregate rating','Votes']

st = StandardScaler()
x2[m2] = st.fit_transform(x2[m2].values)
x2.sample(5)
# Out:
#       Country  Restaurant Name  City  Locality Verbose  Longitude  Latitude  \
# 4172        3             3478    87               559   0.232899  0.219054
# 373         3             2382    43               931   0.234807  0.176400
# 3210        3             5566    87               349   0.226392  0.226659
# 1466        3             1235    50              1057   0.213679  0.177945
# 6605        3              349    87              1026   0.221615  0.227082
#
#       Cuisines  Average Cost for two  Currency  Has Table booking  \
# 4172      1306             -0.320167         4                  0
# 373       1444             -0.505743         4                  0
# 3210      1651             -1.303788         4                  0
# 1466       186              0.352712         4                  0
# 6605       518             -0.156973         4                  0
#
#       Has Online delivery  Aggregate rating  Rating text     Votes
# 4172                    0         -1.608562            3 -1.583091
# 373                     0         -1.608562            3 -0.899159
# 3210                    0          0.102529            0 -0.695518
# 1466                    1          0.020608            0 -0.550030
# 6605                    0         -0.059824            0 -0.343551

# %% [markdown]
# # Checking multicollinearity using Variance Inflation Factor

# %%
vif(x2)
# Out:
#              Column Name  VIF Factor
# 8               Currency   29.923029
# 0                Country   12.889964
# 2                   City   12.834897
# 3       Locality Verbose    5.362410
# 6               Cuisines    4.933082
# 13                 Votes    4.828576
# 11      Aggregate rating    4.460307
# 1        Restaurant Name    3.862597
# 12           Rating text    2.478702
# 7   Average Cost for two    2.018240
# 9      Has Table booking    1.740196
# 10   Has Online delivery    1.611193
# 5               Latitude    1.499913
# 4              Longitude    1.448701

# %%
# Dropping the column Currency

x2.drop(['Currency'],axis=1,inplace=True)

# %%
vif(x2)
# Out:
#              Column Name  VIF Factor
# 2                   City    9.270230
# 0                Country    8.626752
# 3       Locality Verbose    4.946229
# 12                 Votes    4.810025
# 6               Cuisines    4.570853
# 10      Aggregate rating    4.440514
# 1        Restaurant Name    3.764202
# 11           Rating text    2.429165
# 7   Average Cost for two    1.974165
# 8      Has Table booking    1.724207
# 9    Has Online delivery    1.602415
# 5               Latitude    1.486943
# 4              Longitude    1.410859

# %%
sns.countplot(x=y)
print(y.value_counts())
# Out:
# 22.360680    893
# 17.320508    889
# 20.000000    849
# 14.142136    679
# 24.494897    645
#             ...
# 21.095023      1
# 16.431677      1
# 17.748239      1
# 38.078866      1
# 60.415230      1
# Name: Average Cost for two, Length: 112, dtype: int64

# %%
# Importing SMOTE from imblearn
from imblearn.over_sampling import SMOTE
smt = SMOTE()

X,Y = smt.fit_resample(x2,y2)

# %% [markdown]
# # building the ML model

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score

# %%
def random_st_cls(model):
    max_score = 0
    max_rs = 0
    print('\n',model)
    for i in range(1,50):
        x_train, x_test,y_train,y_test= train_test_split(X,Y,test_size = 0.30, random_state = i)
        model.fit(x_train,y_train)
        pred_test = model.predict(x_test)
        score = accuracy_score(y_test,pred_test)
        if score > max_score:
            max_score = score
            max_rs = i
    print("At random state ", max_rs, 'the model is having accuracy score of ', max_score)
    return max_rs

# %%
def model_fit_cls(model, rs):
    x_train, x_test,y_train,y_test= train_test_split(X,Y,test_size = 0.30, random_state = rs)
    model.fit(x_train,y_train)
    pred_test = model.predict(x_test)
    cv_score = cross_val_score(model,X,Y, cv = 5)
    cv_mean = cv_score.mean()
    print(f" Accuracy score is: {accuracy_score(y_test,pred_test)*100:.2f}")
    print ('\n','Confusion matrix:','\n',confusion_matrix(y_test,pred_test))
    print ('\n','Classification Report:','\n',classification_report(y_test,pred_test))
    print("The cv score is ", cv_mean, "and the accuracy score  is ",accuracy_score(y_test,pred_test))
    print(f'\n Difference between accuracy score and cross val score {(accuracy_score(y_test,pred_test)-cv_mean)*100:.2f}')
    print("-"*50)

# %%
def model_cls(m):
    m_rs = random_st_cls(m)
    model_fit_cls(m,m_rs)

# %%
Model_classify = [LogisticRegression(),RandomForestClassifier(), KNeighborsClassifier(),DecisionTreeClassifier(),GradientBoostingClassifier(),AdaBoostClassifier(),SVC(),ExtraTreesClassifier()]

# %%
for i in Model_classify:
    model_cls(i)
# Out:
#  LogisticRegression()
# At random state  49 the model is having accuracy score of  0.625388198757764
#  Accuracy score is: 62.54
#
#  Confusion matrix:
#  [[952 341  46   3]
#  [204 768 208  83]
#  [ 27 285 515 465]
#  [ 13 104 151 987]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.80      0.71      0.75      1342
#            2       0.51      0.61      0.56      1263
#            3       0.56      0.40      0.47      1292
#            4       0.64      0.79      0.71      1255
#
#     accuracy                           0.63      5152
#    macro avg       0.63      0.63      0.62      5152
# weighted avg       0.63      0.63      0.62      5152
#
# The cv score is  0.5138712710212711 and the accuracy score  is  0.625388198757764
#
#  Difference between accuracy score and cross val score 11.15
# --------------------------------------------------
#
#  RandomForestClassifier()
# At random state  48 the model is having accuracy score of  0.984860248447205
#  Accuracy score is: 98.19
#
#  Confusion matrix:
#  [[1307   13    0    0]
#  [   2 1226   22    3]
#  [   1   11 1242   23]
#  [   0    0   18 1284]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.99      0.99      1320
#            2       0.98      0.98      0.98      1253
#            3       0.97      0.97      0.97      1277
#            4       0.98      0.99      0.98      1302
#
#     accuracy                           0.98      5152
#    macro avg       0.98      0.98      0.98      5152
# weighted avg       0.98      0.98      0.98      5152
#
# The cv score is  0.9339687973421025 and the accuracy score  is  0.9819487577639752
#
#  Difference between accuracy score and cross val score 4.80
# --------------------------------------------------
#
#  KNeighborsClassifier()
# At random state  25 the model is having accuracy score of  0.672748447204969
#  Accuracy score is: 67.27
#
#  Confusion matrix:
#  [[ 758  272  157  156]
#  [ 289  720  157  112]
#  [ 111  128  903   94]
#  [  56   54  100 1085]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.62      0.56      0.59      1343
#            2       0.61      0.56      0.59      1278
#            3       0.69      0.73      0.71      1236
#            4       0.75      0.84      0.79      1295
#
#     accuracy                           0.67      5152
#    macro avg       0.67      0.67      0.67      5152
# weighted avg       0.67      0.67      0.67      5152
#
# The cv score is  0.6236944536991589 and the accuracy score  is  0.672748447204969
#
#  Difference between accuracy score and cross val score 4.91
# --------------------------------------------------
#
#  DecisionTreeClassifier()
# At random state  14 the model is having accuracy score of  0.970108695652174
#  Accuracy score is: 96.80
#
#  Confusion matrix:
#  [[1307    5    0    0]
#  [   8 1237   23    1]
#  [   0   24 1209   60]
#  [   0    2   42 1234]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      1312
#            2       0.98      0.97      0.98      1269
#            3       0.95      0.94      0.94      1293
#            4       0.95      0.97      0.96      1278
#
#     accuracy                           0.97      5152
#    macro avg       0.97      0.97      0.97      5152
# weighted avg       0.97      0.97      0.97      5152
#
# The cv score is  0.9219139879567202 and the accuracy score  is  0.9679736024844721
#
#  Difference between accuracy score and cross val score 4.61
# --------------------------------------------------
#
#  GradientBoostingClassifier()
# At random state  48 the model is having accuracy score of  0.9671972049689441
#  Accuracy score is: 96.72
#
#  Confusion matrix:
#  [[1316    2    2    0]
#  [   9 1219   23    2]
#  [   0   38 1187   52]
#  [   0    0   41 1261]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      1320
#            2       0.97      0.97      0.97      1253
#            3       0.95      0.93      0.94      1277
#            4       0.96      0.97      0.96      1302
#
#     accuracy                           0.97      5152
#    macro avg       0.97      0.97      0.97      5152
# weighted avg       0.97      0.97      0.97      5152
#
# The cv score is  0.9442714561720749 and the accuracy score  is  0.9671972049689441
#
#  Difference between accuracy score and cross val score 2.29
# --------------------------------------------------
#
#  AdaBoostClassifier()
# At random state  28 the model is having accuracy score of  0.7589285714285714
#  Accuracy score is: 75.89
#
#  Confusion matrix:
#  [[1271   10    0    0]
#  [  14 1315    3   23]
#  [   0  115 1027  134]
#  [   0    1  942  297]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99      1281
#            2       0.91      0.97      0.94      1355
#            3       0.52      0.80      0.63      1276
#            4       0.65      0.24      0.35      1240
#
#     accuracy                           0.76      5152
#    macro avg       0.77      0.75      0.73      5152
# weighted avg       0.77      0.76      0.73      5152
#
# The cv score is  0.7389354167885323 and the accuracy score  is  0.7589285714285714
#
#  Difference between accuracy score and cross val score 2.00
# --------------------------------------------------
#
#  SVC()
# At random state  24 the model is having accuracy score of  0.34375
#  Accuracy score is: 34.38
#
#  Confusion matrix:
#  [[398 328 330 257]
#  [272 328 383 265]
#  [204 197 686 239]
#  [207 177 522 359]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.37      0.30      0.33      1313
#            2       0.32      0.26      0.29      1248
#            3       0.36      0.52      0.42      1326
#            4       0.32      0.28      0.30      1265
#
#     accuracy                           0.34      5152
#    macro avg       0.34      0.34      0.34      5152
# weighted avg       0.34      0.34      0.34      5152
#
# The cv score is  0.3049200604622497 and the accuracy score  is  0.34375
#
#  Difference between accuracy score and cross val score 3.88
# --------------------------------------------------
#
#  ExtraTreesClassifier()
# At random state  33 the model is having accuracy score of  0.9770962732919255
#  Accuracy score is: 97.24
#
#  Confusion matrix:
#  [[1247   23    1    0]
#  [   7 1234   39    4]
#  [   0   12 1285   28]
#  [   0    0   28 1244]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.99      0.98      0.99      1271
#            2       0.97      0.96      0.97      1284
#            3       0.95      0.97      0.96      1325
#            4       0.97      0.98      0.98      1272
#
#     accuracy                           0.97      5152
#    macro avg       0.97      0.97      0.97      5152
# weighted avg       0.97      0.97      0.97      5152
#
# The cv score is  0.9170223783231137 and the accuracy score  is  0.9724378881987578
#
#  Difference between accuracy score and cross val score 5.54
# --------------------------------------------------

# %% [markdown]
# RandomForestClassifier is the best model with 98% accuracy

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'n_estimators':[100,125,150],
             'criterion': ['gini','entropy'],
             'max_features': ['auto','sqrt','log2'],
             'class_weight':['balanced','balanced_subsample']}
grid2 = GridSearchCV(estimator = RandomForestClassifier(),param_grid=parameters,cv = 3,n_jobs=-1)

# %%
grid2.fit(X,Y)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'class_weight': ['balanced', 'balanced_subsample'],
#                          'criterion': ['gini', 'entropy'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 125, 150]})

# %%
grid2.best_score_
# Out:
# 0.9433962264150942

# %%
grid2.best_params_
# Out:
# {'class_weight': 'balanced_subsample',
#  'criterion': 'gini',
#  'max_features': 'sqrt',
#  'n_estimators': 100}

# %%
x_train, x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.20, random_state = 45)

final_model_cls = RandomForestClassifier(n_estimators=100,criterion='gini',max_features='sqrt',class_weight='balanced_subsample')
final_model_cls.fit(x_train,y_train)
y_pred=final_model_cls.predict(x_test)
print('classification report',classification_report(y_test,y_pred))
print('confusion_matrix:',confusion_matrix(y_test,y_pred))
print('\n Accuracy of Random Forest Classifier After Hyperparameter Tuning',accuracy_score(y_test,y_pred)*100)
# Out:
# classification report               precision    recall  f1-score   support
#
#            1       1.00      0.99      0.99       857
#            2       0.98      0.98      0.98       811
#            3       0.97      0.96      0.96       892
#            4       0.97      0.98      0.97       875
#
#     accuracy                           0.98      3435
#    macro avg       0.98      0.98      0.98      3435
# weighted avg       0.98      0.98      0.98      3435
#
# confusion_matrix: [[847  10   0   0]
#  [  1 795  12   3]
#  [  0  10 854  28]
#  [  0   0  16 859]]
#
#  Accuracy of Random Forest Classifier After Hyperparameter Tuning 97.67103347889375

# %%
imp_id=pd.DataFrame({"Feature Name":x_train.columns,"Importance":final_model_cls.feature_importances_})
fi=imp_id.sort_values(by="Importance",ascending=False)
fi2=fi.head(10)
plt.figure(figsize=(10,8))
sns.barplot(data=fi2,x="Importance",y="Feature Name")
plt.title('Top10 features importance each attributes (ETC)',fontsize=18)
plt.xlabel('Importance',fontsize=16)
plt.ylabel('Feature name', fontsize=16)
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)
x_labels = ["1","0"]
y_labels = ["1","0"]
f, ax = plt.subplots(figsize =(8,4))
sns.heatmap(cm, annot = True, linewidths=0.2, fmt = ".0f", ax=ax, cmap="Blues", xticklabels=x_labels, yticklabels=y_labels)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title('Confusion Matrix')
plt.show()

# %%
import pickle

filename = 'Zomato Classfication model .pkl'
pickle.dump(final_model_cls,open(filename,'wb'))

# %%
original = np.array(y_test)
predicted = np.round(np.array(final_model_cls.predict(x_test)),0)
tom_prediction = pd.DataFrame({'(Original)':original,'(Predicted)':predicted})
tom_prediction.sample(10)
# Out:
#       (Original)  (Predicted)
# 898            4            4
# 3247           3            3
# 2535           3            3
# 2140           3            3
# 1432           4            4
# 2211           3            3
# 1817           4            4
# 3202           4            4
# 2942           1            1
# 1468           3            3
