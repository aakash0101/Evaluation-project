# %% [markdown]
# # Evaluation Project 2 Avacado Project

# %% [markdown]
# # BY: Aakash bindal

# %% [markdown]
# # BATCH NO:DS2401

# %% [markdown]
# # Project Description -
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.

# %% [markdown]
# # What is Avocado and it's importance.
# -Avocado is a fruit consumed by people heavily in the United States.
#
# -Avocados are a source of vitamins C, E, K, and B6, as well as riboflavin, niacin, folate, pantothenic acid, magnesium, and potassium. They also provide lutein, beta carotene, and omega-3 fatty acids. Avocados contain high levels of healthy, beneficial fats, which can help a person feel fuller between meals.

# %% [markdown]
# # Some relevant columns in the dataset:
# • Date - The date of the observation
#
# • AveragePrice - the average price of a single avocado
#
# • type - conventional or organic
#
# • year - the year
#
# • Region - the city or region of the observation
#
# • Total Volume - Total number of avocados sold
#
# • 4046 - Total number of avocados with PLU 4046 sold
#
# • 4225 - Total number of avocados with PLU 4225 sold
#
# • 4770 - Total number of avocados with PLU 4770 sold

# %% [markdown]
# # Inspiration /Label
# The dataset can be seen in two angles to find the region and find the average price .
#
# To Classify as ___Organic___ & ___Conventional Type___.
# To perform ___Regression___ in order to predict the ___Average price___ using Regression model from different ___Year___

# %% [markdown]
# # Dataset Link-
# • https://github.com/FlipRoboTechnologies/ML_-Datasets/blob/main/Avocado/avocado.csv.zip

# %% [markdown]
# # Import some important Libraries

# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"https://raw.githubusercontent.com/aakash0101/Evaluation-project/main/avocado.csv")

# %%
df.head(20)
# Out:
#     Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0            0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1            1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2            2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3            3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4            4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5            5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6            6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7            7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8            8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9            9  2015-10-25          1.07      74338.76   842.40   64757.44
# 10          10  2015-10-18          1.12      84843.44   924.86   75595.85
# ...

# %%
#dropping column that is not useful.
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
print('\nNumber of Rows:', df.shape[0])
print('\nNumber of Columns:', df.shape[1])
# Out:
# Number of Rows: 18249
#
# Number of Columns: 13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# The dataset comprises variables primarily stored as float64 data types, with the variable's , which is stored as int64 and object.

# %%
# Here Date column is shows object dtype. It has to be converted into Datetime data type.
df['Date']=pd.to_datetime(df['Date'])

# %%
#extracting month from Date colunn

df['Month']=pd.to_datetime(df['Date']).dt.month

# %%
#extracting day from Date colunn
df['day'] = pd.to_datetime(df['Date']).dt.day

# %%
df.drop('Date',axis=1,inplace=True)

# %% [markdown]
# We're dropping the date column here because we'll be extracting two additional columns, namely month and day, from the date column.

# %%
df.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# Month             int64
# day               int64
# dtype: object

# %% [markdown]
# After dropping the date column, there are still two columns remaining with the object data type that need further conversion.

# %%
# Printing columns name of the given dataset
df.columns.tolist()
# Out:
# ['AveragePrice',
#  'Total Volume',
#  '4046',
#  '4225',
#  '4770',
#  'Total Bags',
#  'Small Bags',
#  'Large Bags',
#  'XLarge Bags',
#  'type',
#  'year',
#  'region',
#  'Month',
#  'day']

# %% [markdown]
# # Checking Null and Duplicates Values

# %%
print('\nNull Values Count:\n', df.isnull().sum())
# Out:
# Null Values Count:
#  AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# Month           0
# day             0
# dtype: int64

# %%
#we can see  Null values through Heatmap.

sns.heatmap(df.isnull().sum().to_frame())
plt.show()

# %%
#checking for any duplicate values .\
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# It's evident that there are no null values or duplicate values present in the dataset upon observation.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region',
#        'Month', 'day'],
#       dtype='object')

# %%
# returns the total number of unique values for each column.
df.nunique().to_frame("Total No. of Unique Values in each column")
# Out:
#               Total No. of Unique Values in each column
# AveragePrice                                        259
# Total Volume                                      18237
# 4046                                              17702
# 4225                                              18103
# 4770                                              12071
# Total Bags                                        18097
# Small Bags                                        17321
# Large Bags                                        15082
# XLarge Bags                                        5588
# type                                                  2
# year                                                  4
# region                                               54
# Month                                                12
# day                                                  31

# %%
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# # convert categorical value to numerical value

# %%
# convert categorical value to numerical 
value_map={'conventional':0,'organic':1}
df['type']=df['type'].map(value_map)

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Month  day
# 0     8603.62       93.25          0.0     0  2015  Albany     12   27
# 1     9408.07       97.49          0.0     0  2015  Albany     12   20
# 2     8042.21      103.14          0.0     0  2015  Albany     12   13
# 3     5677.40      133.76          0.0     0  2015  Albany     12    6
# 4     5986.26      197.69          0.0     0  2015  Albany     11   29

# %%
df['type'].value_counts()
# Out:
# 0    9126
# 1    9123
# Name: type, dtype: int64

# %%
category_counts = df['type'].value_counts()

plt.bar(category_counts.index, category_counts.values)

plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Count of Category')

plt.show()

# %% [markdown]
# We can visualize that both categories have an equal percentage of data.

# %%
regions=df['region'].value_counts()
plt.figure(figsize=(12,10))
plt.bar(regions.index, regions.values, color='c' )
plt.xticks(rotation='vertical')
plt.xlabel('Region')
plt.ylabel('Count')
plt.title('Count of region')
plt.show()

# %% [markdown]
# From the above graph, it's evident that all regions have an equal ratio of data.

# %%
# Relationship between Average Price and month
sns.catplot(x = "Month", y = "AveragePrice", kind="strip",data=df,height=8, linewidth=2, aspect=2.)

# %% [markdown]
# Here, we observe that the average price for October and November is higher than usual.

# %%
# Relationship between Average Price and year
sns.catplot(x = "year", y = "AveragePrice", kind="strip",data=df,height=8, linewidth=2, aspect=2.)

# %% [markdown]
# Here, we notice that the average price in 2017 is higher than in usual years, while in 2018, it has decreased.

# %%
plt.figure(figsize=(20,18))
sns.set_style('whitegrid')
sns.pointplot(x='AveragePrice', y='region', data=df, hue='type',join=False)
plt.xticks(np.linspace(1,2,5))
plt.xlabel('Region',{'fontsize' : 'large'})
plt.ylabel('AveragePrice',{'fontsize':'large'})
plt.title("Type Average Price in Each Region",{'fontsize':20})
# Out:
# Text(0.5, 1.0, 'Type Average Price in Each Region')

# %% [markdown]
# Based on the above observations, we can conclude that:
#
# The price of organic avocados is high in the Hartford-Springfield and San Francisco regions.
# The average price for conventional avocados is below $1.50.
# Organic avocados have a higher price per unit compared to conventional avocados.

# %% [markdown]
# # Lable Encoding

# %%
from sklearn.preprocessing import LabelEncoder

df['region'] = LabelEncoder().fit_transform(df['region'])
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region  Month  day
# ...

# %% [markdown]
# We've successfully converted the 'region' column from categorical to numeric values.

# %% [markdown]
# # Statistical Analysis

# %%
df.describe().T
# Out:
#                 count           mean           std      min       25%  \
# AveragePrice  18249.0       1.405978  4.026766e-01     0.44      1.10
# Total Volume  18249.0  850644.013009  3.453545e+06    84.56  10838.58
# 4046          18249.0  293008.424531  1.264989e+06     0.00    854.07
# 4225          18249.0  295154.568356  1.204120e+06     0.00   3008.78
# 4770          18249.0   22839.735993  1.074641e+05     0.00      0.00
# Total Bags    18249.0  239639.202060  9.862424e+05     0.00   5088.64
# Small Bags    18249.0  182194.686696  7.461785e+05     0.00   2849.42
# Large Bags    18249.0   54338.088145  2.439660e+05     0.00    127.47
# XLarge Bags   18249.0    3106.426507  1.769289e+04     0.00      0.00
# type          18249.0       0.499918  5.000137e-01     0.00      0.00
# year          18249.0    2016.147899  9.399385e-01  2015.00   2015.00
# region        18249.0      26.495644  1.558379e+01     0.00     13.00
# ...

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df.describe().T,linewidth=0.3,fmt='0.3f' ,annot=True,cmap='gist_heat')
# Out:
# <Axes: >

# %% [markdown]
# Statistical analysis reveals right skewness in the feature distributions. Consistent counts indicate a complete dataset. Potential outliers, particularly in 'Total Volume', '4225', '4046', and 'Total Bags', warrant attention. The heatmap emphasizes the need for feature scaling.

# %% [markdown]
# # Outlier Detection

# %%
plt.figure(figsize=(25,25),facecolor='pink')
index=1
for column in df:
    if index <=13:
        ax = plt.subplot(5,3,index)
        sns.boxplot(df[column], palette='coolwarm')
        plt.xlabel(column,fontsize=20)
    index+=1
plt.show()

# %% [markdown]
# We can observe outliers in the following columns: 'AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', and 'XLarge Bags'. This is likely because the data has not been scaled.

# %% [markdown]
# # Removing of outliers

# %%
from scipy.stats import zscore

# Specify the columns to remove outliers
columns_to_remove_outliers = ['Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags']

# Calculate z-scores for each specified column
z_scores = df[columns_to_remove_outliers].apply(zscore)

# Set a threshold for z-scores (e.g., 3)
threshold = 3

# Remove rows with z-scores beyond the threshold in any specified column
df1 = df[(z_scores.abs() < threshold).all(axis=1)]
#Shape before removing outliers
print('Shape of dataset before removing outliers :', df.shape)
#Shape after removing outliers
print('Shape of dataset after removing outliers :', df1.shape)
print("Total Drop Rows are ",df.shape[0]-df1.shape[0])
# Out:
# Shape of dataset before removing outliers : (18249, 14)
# Shape of dataset after removing outliers : (17782, 14)
# Total Drop Rows are  467

# %%
#Data Loss
print('Percentage Data Loss :',((18249-17782)/18249)*100,'%')
# Out:
# Percentage Data Loss : 2.55904433119623 %

# %% [markdown]
# # Checking Skewness of dataset

# %%
plt.figure(figsize=(20,25), facecolor='lightyellow')
plotnumber=1
for column in df1:
    if plotnumber <=13:
        ax = plt.subplot(5,4,plotnumber)
        sns.distplot(df1[column], color='y',hist=False,kde_kws={"shade": True})
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# Skewness is noticeable in the dataset, indicating an asymmetrical distribution of values either to the right or left.

# %%
df1.skew()
# Out:
# AveragePrice    0.560969
# Total Volume    3.782060
# 4046            4.928850
# 4225            4.472729
# 4770            5.137120
# Total Bags      4.082103
# Small Bags      4.238647
# Large Bags      5.072468
# XLarge Bags     6.159391
# type           -0.052210
# year            0.220792
# region          0.005773
# Month           0.098217
# day             0.011251
# dtype: float64

# %% [markdown]
# The optimal range for skewness is between -0.5 and 0.5.
#
# 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', and 'XLarge Bags' are positively skewed and need to be transformed.

# %% [markdown]
# # Removing Skewness of Dataset using the LOGARITHMIC Transformation.
# Applying the logarithmic transformation tends to compress higher values more than lower values, helping to reduce right skewness.

# %%
column_name = ['Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags']

# Log transformation
df1[column_name] = np.log1p(df1[column_name])

# Plot the transformed data to check for skewness
sns.histplot(df1[column_name], kde=True)
plt.title('Log-Transformed Data Distribution')
plt.show()

# %%
#checking skewness after removing of skewness
df1.skew()
# Out:
# AveragePrice    0.560969
# Total Volume   -0.039041
# 4046           -0.408827
# 4225           -0.595360
# 4770            0.079074
# Total Bags     -0.394347
# Small Bags     -0.782875
# Large Bags     -0.603830
# XLarge Bags     1.225926
# type           -0.052210
# year            0.220792
# region          0.005773
# Month           0.098217
# day             0.011251
# dtype: float64

# %% [markdown]
# Skewness of dataset is shorted.

# %% [markdown]
# # Correlation of Dataset

# %%
df1.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.576957 -0.531830 -0.429352 -0.492918
# Total Volume     -0.576957      1.000000  0.875507  0.899785  0.818355
# 4046             -0.531830      0.875507  1.000000  0.740022  0.724934
# 4225             -0.429352      0.899785  0.740022  1.000000  0.775408
# 4770             -0.492918      0.818355  0.724934  0.775408  1.000000
# Total Bags       -0.567930      0.926452  0.763258  0.768688  0.750925
# Small Bags       -0.479438      0.862657  0.716206  0.694881  0.724027
# Large Bags       -0.463904      0.643727  0.550727  0.584879  0.525859
# XLarge Bags      -0.359220      0.614847  0.539795  0.543259  0.604235
# type              0.608447     -0.801035 -0.714668 -0.730636 -0.779431
# year              0.099910      0.077904 -0.001748  0.003861 -0.053770
# region            0.010428      0.065468  0.157078  0.031982  0.034927
# ...

# %%
# we can analyse correlation through heatmap
plt.figure(figsize=(12,10))
sns.heatmap(df1.corr(),linewidth=0.1,fmt='0.3f',annot=True,cmap='Greens')
# Out:
# <Axes: >

# %%
df1.corr()['AveragePrice'].sort_values(ascending = False)
# Out:
# AveragePrice    1.000000
# type            0.608447
# Month           0.157900
# year            0.099910
# day             0.024742
# region          0.010428
# XLarge Bags    -0.359220
# 4225           -0.429352
# Large Bags     -0.463904
# Small Bags     -0.479438
# 4770           -0.492918
# 4046           -0.531830
# Total Bags     -0.567930
# Total Volume   -0.576957
# Name: AveragePrice, dtype: float64

# %%
plt.figure(figsize = (17,7))
df1.corr()['AveragePrice'].sort_values(ascending = False).drop(['AveragePrice']).plot(kind='bar',color = 'y')
plt.xlabel('Features',fontsize=16)
plt.ylabel('AveragePrice',fontsize=16)
plt.title('Correlation of features with Target Variable AveragePrice',fontsize = 18)
plt.show()

# %% [markdown]
# We can observe the correlation of the dataset through the heatmap and bar graph.
#
# 'type', 'year', 'region', and 'day' have a positive correlation with 'Average Price'. The rest of the columns have a negative correlation with 'Average Price'.

# %% [markdown]
# # Checking multicollinearity using Variance Inflation Factor

# %%
#Checking multicollinearity using Varience-inflation-factor (VIF)

from statsmodels.stats.outliers_influence import variance_inflation_factor

vif= pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif['Features'] = df1.columns
vif
# Out:
#             VIF      Features
# 0     27.330381  AveragePrice
# 1   1061.677224  Total Volume
# 2     47.804940          4046
# 3    114.256045          4225
# 4      9.179364          4770
# 5    479.525237    Total Bags
# 6    153.956418    Small Bags
# 7     11.767357    Large Bags
# 8      2.537963   XLarge Bags
# 9      8.206057          type
# 10   194.343738          year
# 11     4.205585        region
# 12     4.276033         Month
# 13     4.199113           day

# %% [markdown]
# VIF checks for multicollinearity in regression. High VIF means strong correlation between predictors, impacting result reliability. Low VIF improves model accuracy by identifying and addressing problematic variables.
#
# Here, we can see that the columns 'XLarge Bags', 'region', 'Month' and 'day' have very low correlation with the target variable. Therefore, we can drop these columns.

# %%
df1.drop([ 'XLarge Bags' , 'region', 'Month','day'],axis=1,inplace=True)

# %%
df1.shape
# Out:
# (17782, 10)

# %%
df1.head()
# Out:
#    AveragePrice  Total Volume      4046       4225      4770  Total Bags  \
# 0          1.33     11.070344  6.944801  10.905146  3.895080    9.070833
# 1          1.35     10.912867  6.515127  10.706381  4.083115    9.159737
# 2          0.93     11.680313  6.679222  11.600485  4.879007    9.005325
# 3          1.08     11.277116  7.032624  11.184108  4.298373    8.667708
# 4          1.28     10.840377  6.848515  10.688288  4.340944    8.729874
#
#    Small Bags  Large Bags  type  year
# 0    9.060055    4.545951     0  2015
# 1    9.149429    4.589955     0  2015
# 2    8.992584    4.645736     0  2015
# 3    8.644425    4.903495     0  2015
# 4    8.697389    5.291746     0  2015

# %% [markdown]
# # splitting the dataset

# %% [markdown]
# # Classifying The Types of Avocado

# %%
#spliting Data for Classification
X_= df1[['AveragePrice', '4046', '4225', '4770', 'Small Bags', 'Large Bags']]
Y=df1.type

# %%
Y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 18244    1
# 18245    1
# 18246    1
# 18247    1
# 18248    1
# Name: type, Length: 17782, dtype: int64

# %% [markdown]
# # Standard Scaling of Dataset

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=pd.DataFrame(scaler.fit_transform(X_),columns = X_.columns)
x_scaled
# Out:
#        AveragePrice      4046      4225      4770  Small Bags  Large Bags
# 0         -0.212660 -0.581441  0.436485 -0.239935   -0.206003   -0.643231
# 1         -0.162942 -0.713611  0.364388 -0.193155   -0.169954   -0.631503
# 2         -1.207026 -0.663134  0.688705  0.004847   -0.233217   -0.616636
# 3         -0.834139 -0.554426  0.537673 -0.139603   -0.373646   -0.547937
# 4         -0.336956 -0.611059  0.357825 -0.129013   -0.352283   -0.444460
# ...             ...       ...       ...       ...         ...         ...
# 17777      0.533114 -0.372332 -0.859180 -1.208956   -0.037463   -0.236933
# 17778      0.731987 -0.538631 -0.566134 -1.208956   -0.190534   -0.312654
# 17779      1.129733 -0.538574 -0.687886  0.430905   -0.172373   -0.850470
# 17780      1.278888 -0.462298 -0.617164  0.430587   -0.109867   -0.806909
# 17781      0.508255 -0.265776 -0.702464  0.139051   -0.072212   -0.976316
#
# [17782 rows x 6 columns]

# %% [markdown]
# # ML Model Building

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
Model= [LogisticRegression(),RandomForestClassifier(),DecisionTreeClassifier(), SVC(),ExtraTreesClassifier(),  GradientBoostingClassifier()]

# %%
for i in range(1,50):
    x_train,x_test,y_train,y_test = train_test_split(x_scaled,Y,test_size = .20, random_state=i)
    for m in Model:
        maxAcc = 0
        maxRs = 0
        m.fit(x_train,y_train)
        m.score(x_train,y_train)
        pred = m.predict(x_test)
        acc = accuracy_score(y_test,pred)
        if acc>maxAcc:
            maxAcc = acc
            maxRs=i
            mod=m
print("For Model",mod,"Best Accuracy is:", maxAcc, "on Random State:", maxRs)
# Out:
# For Model GradientBoostingClassifier() Best Accuracy is: 0.9828507168962609 on Random State: 49

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x_scaled,Y, test_size= 0.2, random_state=49 )

# %%
#Splitting the data into training and testing Data.
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (14225, 6)
# (3557, 6)
# (14225,)
# (3557,)

# %%
from sklearn.model_selection import cross_val_score
for m in Model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predmt = m.predict(x_train)
    predm=m.predict(x_test)
    print('-----------------',m,'---------------------------')
    print(f" Accuracy score for training data: {accuracy_score(y_train,predmt)*100:.2f}")
    print(f" Accuracy score for testing data: {accuracy_score(y_test,predm)*100:.2f}")
    print ('\n','Confusion matrix:','\n',confusion_matrix(y_test,predm))
    print ('\n','Classification Report:','\n',classification_report(y_test,predm))
    score = cross_val_score(m,x_scaled,Y,cv=5)
    print('\n',f"Cross val score: {score.mean()*100:.2f}%")
    print(f'\n Difference between accuracy score and cross val score {(accuracy_score(y_test,predm)-score.mean())*100:.2f}')
    print('\n')
# Out:
# ----------------- LogisticRegression() ---------------------------
#  Accuracy score for training data: 94.66
#  Accuracy score for testing data: 95.05
#
#  Confusion matrix:
#  [[1690   86]
#  [  90 1691]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      1776
#            1       0.95      0.95      0.95      1781
#
#     accuracy                           0.95      3557
#    macro avg       0.95      0.95      0.95      3557
# weighted avg       0.95      0.95      0.95      3557
#
#
#  Cross val score: 94.11%
#
#  Difference between accuracy score and cross val score 0.95
#
#
# ----------------- RandomForestClassifier() ---------------------------
#  Accuracy score for training data: 100.00
#  Accuracy score for testing data: 99.24
#
#  Confusion matrix:
#  [[1768    8]
#  [  19 1762]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
# ...

# %% [markdown]
# # Prediction Based on Model

# %%
prediction_=pd.DataFrame({'predicted values':predm,'actual values':y_test})
prediction_
# Out:
#        predicted values  actual values
# 4225                  0              0
# 14957                 1              1
# 10866                 1              1
# 3368                  0              0
# 17330                 1              1
# ...                 ...            ...
# 3850                  0              0
# 11187                 1              1
# 3318                  0              0
# 3292                  0              0
# 17049                 1              1
#
# [3557 rows x 2 columns]

# %%
plt.figure(figsize=(5,5))
plt.scatter(predm,y_test, c='g')
plt1 = max(max(predm), max(y_test))
plt2 = min(min(predm), min(y_test))
plt.plot([plt1, plt2], [plt1, plt2], 'b-')
plt.xlabel('Actual Values', fontsize=15)
plt.ylabel('Predicted Values', fontsize=15)
plt.title("Random Forest Regressor")
plt.show()

# %% [markdown]
# The average price, total exchanges, and total volume are equally distributed among all the columns. For building this model, we are utilizing both regression and classification techniques. The RandomForestClassifier is the best performing model, achieving 100% accuracy.

# %% [markdown]
# # Saving Best Model

# %%
import joblib

# Create and train the model
model = RandomForestClassifier( n_estimators=100,
    criterion='gini',
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    bootstrap=True,
    random_state=42)
model.fit(X_train, y_train)
model.fit(X_train, y_train)

# Save the model to a file
joblib.dump(model, 'avocado_model.joblib')
# Out:
# ['avocado_model.joblib']
