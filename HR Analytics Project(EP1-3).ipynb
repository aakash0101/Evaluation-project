# %% [markdown]
# # Evaluation Project 3 HR Analytics Project- Understanding the Attrition in HR

# %% [markdown]
# # BY:Aakash bindal

# %% [markdown]
# # BATCH NO:DS2401

# %% [markdown]
# #Project Description
#
# Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?

# %% [markdown]
# # HR Analytics
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.

# %% [markdown]
# # Attrition in HR
# Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.
#
# How does Attrition affect companies? and how does HR Analytics help in analyzing attrition? We will discuss the first question here and for the second question, we will write the code and try to understand the process step by step.

# %% [markdown]
# # Attrition affecting Companies
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.

# %% [markdown]
# # Dataset Link-
# • https://github.com/FlipRoboTechnologies/ML_-Datasets/blob/main/HR%20Analytics/ibm-hr-analytics-employee-attrition-performance.zip

# %% [markdown]
# # Column Details

# %% [markdown]
# #NOTE:-
# 1.AGE = consists Numerical Value
#
# 2.ATTRITION = consists Employee leaving the company (1=no, 2=yes)
#
# 3.BUSINESS TRAVEL = consists (1=No Travel, 2=Travel Frequently, 3=Tavel Rarely)
#
# 4.DAILY RATE = consists Numerical Value - Salary Level
#
# 5.DEPARTMENT = consists (1=HR, 2=R&D, 3=Sales)
#
# 6.DISTANCE FROM HOME = consists Numerical Value - THE DISTANCE FROM WORK TO HOME
#
# 7.EDUCATION = consists Numerical Value
#
# 8.EDUCATION FIELD = consists (1=HR, 2=LIFE SCIENCES, 3=MARKETING, 4=MEDICAL SCIENCES, 5=OTHERS, 6= TEHCNICAL)
#
# 9.EMPLOYEE COUNT = consists Numerical Value
#
# 10.EMPLOYEE NUMBER = consists Numerical Value - EMPLOYEE ID
#
# 11.ENVIROMENT SATISFACTION = consists Numerical Value - SATISFACTION WITH THE ENVIROMENT
#
# 12.GENDER = consists (1=FEMALE, 2=MALE)
#
# 13.HOURLY RATE = consists Numerical Value - HOURLY SALARY
#
# 14.JOB INVOLVEMENT= consists Numerical Value - JOB INVOLVEMENT
#
# 15.JOB LEVEL = consists Numerical Value - LEVEL OF JOB
#
# 16.JOB ROLE= consists(1=HC REP, 2=HR, 3=LAB TECHNICIAN, 4=MANAGER, 5= Manufacturing Director, 6= REASEARCH DIRECTOR, 7= RESEARCH SCIENTIST, 8=SALES EXECUTIEVE, 9= SALES REPRESENTATIVE)
#
# 17.JOB SATISFACTION= consists Numerical Value - SATISFACTION WITH THE JOB
#
# 18.MARITAL STATUS = consists (1=DIVORCED, 2=MARRIED, 3=SINGLE)
#
# 19.MONTHLY INCOME = consists Numerical Value - MONTHLY SALARY
#
# 20.MONTHY RATE = consists Numerical Value - MONTHY RAT
#
# 21.NUMCOMPANIES WORKED = consists Numerical Value - NO. OF COMPANIES WORKED AT
#
# 22.OVER 18 = consists (1=YES, 2=NO)
#
# 23.OVERTIME=consists (1=NO, 2=YES)
#
# 24.PERCENT SALARY HIKE = consists Numerical Value - PERCENTAGE INCREASE IN SALARY
#
# 25.PERFORMANCE RATING = consists Numerical Value - ERFORMANCE RATING
#
# 26.RELATIONS SATISFACTION = consists Numerical Value - RELATIONS SATISFACTION
#
# 27.STANDARD HOURS = consists Numerical Value - STANDARD HOURS
#
# 28.STOCK OPTIONS LEVEL = consists Numerical Value - STOCK OPTIONS
#
# 29.TOTAL WORKING YEARS = consists Numerical Value - TOTAL YEARS WORKED
#
# 30.TRAINING TIMES LAST YEAR= consists Numerical Value - HOURS SPENT TRAINING
#
# 31.WORK LIFE BALANCE = consists Numerical Value - TIME SPENT BEWTWEEN WORK AND OUTSIDE
#
# 32.YEARS AT COMPANY = consists Numerical Value - TOTAL NUMBER OF YEARS AT THE COMPNAY
#
# 33.YEARS IN CURRENT ROLE = consists Numerical Value -YEARS IN CURRENT ROLE
#
# 34.YEARS SINCE LAST PROMOTION = consists Numerical Value - LAST PROMOTION
#
# 35.YEARS WITH CURRENT MANAGER = consists Numerical Value - YEARS SPENT WITH CURRENT MANAGER

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Using double backslashes to escape the backslashes in the file path
df = pd.read_csv("https://raw.githubusercontent.com/aakash0101/Evaluation-project/main/WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# The dataset comprises variables primarily stored as int64 data types, with the variable's , which is stored as object.

# %%
print('Number of Rows:',df.shape[0])
print('Number of Columns:',df.shape[1])
# Out:
# Number of Rows: 1470
# Number of Columns: 35

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# Indicates that there are no null values within the dataset.

# %%
#checking null values
sns.heatmap(df.isnull().sum().to_frame())
# Out:
# <Axes: >

# %% [markdown]
# Indicates that there are no null values within the dataset.

# %% [markdown]
# # Extracting Categorical columns

# %%
cat = (df.dtypes == 'object')
print("Categorical variables:",len(list(cat[cat].index)))
# Out:
# Categorical variables: 9

# %%
categorical_columns = df.select_dtypes(include=['object']).columns

# Displaying the result
print("Categorical Columns:",categorical_columns)
# Out:
# Categorical Columns: Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # Encoding Categorical columns data to Numeric data

# %%
#count of  categorical value
print(df['Attrition'].value_counts())
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
# encoding attrition columns.
df= df.replace({"Attrition":{"No":0, "Yes":1 }})

# %%
#count of  categorical value
print(df['BusinessTravel'].value_counts())
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
# encoding Bussiness Travel columns.
df= df.replace({"BusinessTravel":{"Non-Travel":1, "Travel_Frequently":2,"Travel_Rarely":3 }})

# %%
# count of categorical value.
print(df['Department'].value_counts())
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
# encoding Department column.
df= df.replace({"Department":{"Human Resources":1, "Research & Development":2, "Sales":3 }})

# %%
# encoding Educationfield columns.
print(df['EducationField'].value_counts())
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
#encoding EducationFiield columns.
df= df.replace({"EducationField":{"Human Resources":1, "Life Sciences":2, 
                                  "Marketing":3, "Medical":4,
                                  "Other":5, "Technical Degree":6 }})

# %%
# value count of gender column
print(df['Gender'].value_counts())
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
#encoding Gender column
df=df.replace({'Gender':{'Male':1,'Female':0}})

# %%
# value count of JobRole 
print(df['JobRole'].value_counts())
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
#encoding of Jobrole column
df=df.replace({'JobRole':{'Sales Executive':1,'Research Scientist':2,'Laboratory Technician':3,'Manufacturing Director':4,
                          'Healthcare Representative':5,'Manager':6,'Sales Representative':7,'Research Director':8,
                         'Human Resources':9}})

# %%
#value count of MaritalStatus column
print(df['MaritalStatus'].value_counts())
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
#encodeing of MaritalStatus
df=df.replace({'MaritalStatus':{'Married':1,'Single':2,'Divorced':3}})

# %%
#value count of Overtime  column
print(df['OverTime'].value_counts())
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
#encoding of overtime column
df=df.replace({'OverTime':{'No':0,'Yes':1}})

# %%
#value count of Ovetime column
print(df['Over18'].value_counts())
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
df=df.replace({'Over18':{'Y':1}})

# %%
#checking encoded value
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int64
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int64
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# We can see that after performing encoding, there are no object data types remaining; all columns are now of int64 datatype.

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               3       1102           3                 1
# 1   49          0               2        279           2                 8
# 2   37          1               3       1373           2                 2
# 3   33          0               2       1392           2                 3
# 4   27          0               3        591           2                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               2              1               1  ...
# 1          1               2              1               2  ...
# 2          2               5              1               4  ...
# 3          4               2              1               5  ...
# 4          1               4              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
df.drop(columns=['StandardHours','EmployeeCount','Over18'],axis=1,inplace=True)

# %% [markdown]
# We can drop the 'Employee Count', 'Over18', and 'Standard Hours' columns because they contain a single value throughout.

# %%
print('columns left After Droping useless columns:',df.shape[1])
# Out:
# columns left After Droping useless columns: 32

# %% [markdown]
# # Statistical Analysis

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# Attrition                 1470.0      0.161224     0.367863     0.0     0.00
# BusinessTravel            1470.0      2.607483     0.665455     1.0     2.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# Department                1470.0      2.260544     0.527792     1.0     2.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EducationField            1470.0      3.247619     1.331369     1.0     2.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# Gender                    1470.0      0.600000     0.490065     0.0     0.00
# ...

# %% [markdown]
# The dataset contains 1470 unique rows and 32 columns, with no null values present.
# A no notable disparity are present in  column suggests skewness and possible outliers.
#
# there is skewness and outliers are present in the datastes as well.

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df.describe().T,linewidth=0.3,fmt='0.3f' ,annot=True,cmap='gist_heat')
# Out:
# <Axes: >

# %% [markdown]
# This statistical analysis indicates a high potential for outliers in the dataset.

# %% [markdown]
# # Outlier Detection

# %%
plt.figure(figsize=(30,60),facecolor='pink')
index=1
for column in df:
    if index <=32:
        ax = plt.subplot(11,3,index)
        sns.boxplot(df[column], palette='coolwarm')
        plt.xlabel(column,fontsize=20)
    index+=1
plt.show()

# %% [markdown]
# The following columns have outliers: [Attrition, MonthlyIncome, NumCompaniesWorked, PerformanceRating, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager].

# %% [markdown]
# # Removing of Outliers

# %%
from scipy.stats import zscore
# Specify the columns to remove outliers
columns_to_remove_outliers = ['Attrition','MonthlyIncome','NumCompaniesWorked',
'PerformanceRating','StockOptionLevel','TotalWorkingYears', 'TrainingTimesLastYear','YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager']
# Calculate z-scores for each specified column
z_scores = df[columns_to_remove_outliers].apply(zscore)

# Set a threshold for z-scores (e.g., 3)
threshold = 3

# Remove rows with z-scores beyond the threshold in any specified column
df1 = df[(z_scores.abs() < threshold).all(axis=1)]

# %%
print('Shape of dataset before removing outliers :', df.shape)
print('Shape of dataset after removing outliers :', df1.shape)
print("Total Drop Rows are ",df.shape[0]-df1.shape[0])
# Out:
# Shape of dataset before removing outliers : (1470, 32)
# Shape of dataset after removing outliers : (1387, 32)
# Total Drop Rows are  83

# %%
#calculating Data Loss
print('Percentage Data Loss :',((1470-1387)/1470)*100,'%')
# Out:
# Percentage Data Loss : 5.646258503401361 %

# %% [markdown]
# # Checking Skewness of Dataset

# %%
plt.figure(figsize=(30,60), facecolor='coral')
plotnumber=1
for column in df1:
    if plotnumber <=32:
        ax = plt.subplot(11,3,plotnumber)
        sns.distplot(df1[column], color='r',hist=False,kde_kws={"shade": True})
        plt.xlabel(column,fontsize=30)
    plotnumber+=1
plt.show()

# %%
df1.skew()
# Out:
# Age                         0.472280
# Attrition                   1.805983
# BusinessTravel             -1.426774
# DailyRate                  -0.017078
# Department                  0.183919
# DistanceFromHome            0.954752
# Education                  -0.289024
# EducationField              0.544868
# EmployeeNumber              0.018931
# EnvironmentSatisfaction    -0.325285
# Gender                     -0.417296
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    1.126075
# JobRole                     0.869228
# JobSatisfaction            -0.345612
# MaritalStatus               0.450413
# MonthlyIncome               1.544770
# MonthlyRate                 0.030596
# NumCompaniesWorked          1.037715
# OverTime                    0.954751
# PercentSalaryHike           0.800592
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.962332
# ...

# %% [markdown]
# The optimal range for skewness is -0.5 to 0.5. The following columns are right-skewed: ['Attrition', 'BusinessTravel', 'DistanceFromHome', 'JobLevel', 'JobRole', 'MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'].

# %% [markdown]
# Almost all of the above datasets with values ranging from -0.5 to 0.5 are considered skewed columns.

# %% [markdown]
# # Correlation of Dataset

# %%
df1.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159366        0.022340   0.021946
# Attrition                -0.159366   1.000000       -0.001041  -0.057220
# BusinessTravel            0.022340  -0.001041        1.000000  -0.004606
# DailyRate                 0.021946  -0.057220       -0.004606   1.000000
# Department               -0.038242   0.063637       -0.003521  -0.005398
# DistanceFromHome         -0.011265   0.081788       -0.032873  -0.008171
# Education                 0.198502  -0.032703       -0.010560  -0.018442
# EducationField           -0.032676   0.023585        0.022576   0.040645
# EmployeeNumber           -0.002704  -0.010169       -0.013273  -0.044886
# EnvironmentSatisfaction   0.014098  -0.112393        0.001183   0.033123
# Gender                   -0.039430   0.036252       -0.025364  -0.005242
# HourlyRate                0.025465  -0.001532        0.025424   0.014279
# ...

# %%
# we can analyse correlation through heatmap
plt.figure(figsize=(20,15))
sns.heatmap(df1.corr(),linewidth=0.1,fmt='0.3f',annot=True,cmap='Greens')
# Out:
# <Axes: >

# %%
df1.corr()['Attrition'].sort_values(ascending = False)
# Out:
# Attrition                   1.000000
# OverTime                    0.257237
# DistanceFromHome            0.081788
# Department                  0.063637
# NumCompaniesWorked          0.050314
# Gender                      0.036252
# EducationField              0.023585
# MaritalStatus               0.021732
# MonthlyRate                 0.014888
# PerformanceRating           0.010781
# BusinessTravel             -0.001041
# HourlyRate                 -0.001532
# PercentSalaryHike          -0.006267
# EmployeeNumber             -0.010169
# JobRole                    -0.017923
# YearsSinceLastPromotion    -0.029263
# Education                  -0.032703
# RelationshipSatisfaction   -0.052344
# DailyRate                  -0.057220
# TrainingTimesLastYear      -0.057285
# WorkLifeBalance            -0.062492
# EnvironmentSatisfaction    -0.112393
# JobSatisfaction            -0.114206
# JobInvolvement             -0.133957
# StockOptionLevel           -0.136676
# ...

# %%
plt.figure(figsize = (17,7))
df1.corr()['Attrition'].sort_values(ascending = False).drop(['Attrition']).plot(kind='bar',color = 'b')
plt.xlabel('Features',fontsize=16)
plt.ylabel('AveragePrice',fontsize=16)
plt.title('Correlation of features with Target Variable AveragePrice',fontsize = 18)
plt.show()

# %% [markdown]
# We can observe the correlation of the dataset through the heatmap and bar graph.
#
# 'OverTime' and 'DistanceFromHome' have a positive correlation with 'Attrition'. The rest of the columns have a negative correlation with 'Attrition'.

# %% [markdown]
# # Checking multicollinearity using Varience-inflation-factor (VIF)

# %%
#Checking multicollinearity using Varience-inflation-factor (VIF)

from statsmodels.stats.outliers_influence import variance_inflation_factor

vif= pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif['Features'] = df1.columns
vif
# Out:
#            VIF                  Features
# 0    31.251959                       Age
# 1     1.533499                 Attrition
# 2    15.409561            BusinessTravel
# 3     5.062365                 DailyRate
# 4    24.074035                Department
# 5     2.345728          DistanceFromHome
# 6     9.381988                 Education
# 7     6.953336            EducationField
# 8     3.926557            EmployeeNumber
# 9     7.341753   EnvironmentSatisfaction
# 10    2.549257                    Gender
# 11   11.352179                HourlyRate
# 12   15.572138            JobInvolvement
# 13   47.079123                  JobLevel
# 14    4.696362                   JobRole
# 15    7.217829           JobSatisfaction
# 16    6.046249             MaritalStatus
# 17   29.379695             MonthlyIncome
# 18    5.130779               MonthlyRate
# 19    2.756225        NumCompaniesWorked
# 20    1.569847                  OverTime
# 21   43.396401         PercentSalaryHike
# ...

# %% [markdown]
# VIF checks for multicollinearity in regression. High VIF means strong correlation between predictors, impacting result reliability. Low VIF improves model accuracy by identifying and addressing problematic variables.
#
# Here, we observe that the columns (EmployeeNumber, Gender, OverTime, StockOptionLevel, YearsSinceLastPromotion) have very low correlation with the target variable. Therefore, we can drop these columns.

# %%
df1.drop(['EmployeeNumber', 'Gender', 'OverTime', 'StockOptionLevel', 'YearsSinceLastPromotion'],axis=1,inplace=True)

# %%
df1.shape
# Out:
# (1387, 27)

# %%
df1.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               3       1102           3                 1
# 1   49          0               2        279           2                 8
# 2   37          1               3       1373           2                 2
# 3   33          0               2       1392           2                 3
# 4   27          0               3        591           2                 2
#
#    Education  EducationField  EnvironmentSatisfaction  HourlyRate  ...  \
# 0          2               2                        2          94  ...
# 1          1               2                        3          61  ...
# 2          2               5                        4          92  ...
# 3          4               2                        4          56  ...
# 4          1               4                        1          40  ...
#
#    NumCompaniesWorked  PercentSalaryHike  PerformanceRating  \
# ...

# %% [markdown]
# # Splitting the datasets

# %%
X = df[['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EnvironmentSatisfaction']]

# %%
#Target variable
y= df.Attrition
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int64

# %% [markdown]
# # Standard Scaling of Dataset

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=pd.DataFrame(scaler.fit_transform(X),columns = X.columns)
x_scaled
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.446350        0.590048   0.742527    1.401512         -1.010909
# 1     1.322365       -0.913194  -1.297775   -0.493817         -0.147150
# 2     0.008343        0.590048   1.414363   -0.493817         -0.887515
# 3    -0.429664       -0.913194   1.461466   -0.493817         -0.764121
# 4    -1.086676        0.590048  -0.524295   -0.493817         -0.887515
# ...        ...             ...        ...         ...               ...
# 1465 -0.101159       -0.913194   0.202082   -0.493817          1.703764
# 1466  0.227347        0.590048  -0.469754   -0.493817         -0.393938
# 1467 -1.086676        0.590048  -1.605183   -0.493817         -0.640727
# 1468  1.322365       -0.913194   0.546677    1.401512         -0.887515
# 1469 -0.320163        0.590048  -0.432568   -0.493817         -0.147150
#
#       Education  EducationField  EnvironmentSatisfaction
# ...

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
Model= [LogisticRegression(),RandomForestClassifier(),DecisionTreeClassifier(), SVC(),ExtraTreesClassifier(),  GradientBoostingClassifier()]

# %%
for i in range(1,50):
    x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size = .20, random_state=i)
    for m in Model:
        maxAcc = 0
        maxRs = 0
        m.fit(x_train,y_train)
        m.score(x_train,y_train)
        pred = m.predict(x_test)
        acc = accuracy_score(y_test,pred)
        if acc>maxAcc:
            maxAcc = acc
            maxRs=i
            mod=m
print("For Model",mod,"Best Accuracy is:", maxAcc, "on Random State:", maxRs)
# Out:
# For Model GradientBoostingClassifier() Best Accuracy is: 0.8333333333333334 on Random State: 49

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x_scaled,y, test_size= 0.2, random_state=49 )

# %%
#Splitting the data into training and testing Data.
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1176, 8)
# (294, 8)
# (1176,)
# (294,)

# %%
from sklearn.model_selection import cross_val_score
for m in Model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predmt = m.predict(x_train)
    predm=m.predict(x_test)
    print('-----------------',m,'---------------------------')
    print(f" Accuracy score for training data: {accuracy_score(y_train,predmt)*100:.2f}")
    print(f" Accuracy score for testing data: {accuracy_score(y_test,predm)*100:.2f}")
    print ('\n','Confusion matrix:','\n',confusion_matrix(y_test,predm))
    print ('\n','Classification Report:','\n',classification_report(y_test,predm))
    score = cross_val_score(m,x_scaled,y,cv=5)
    print('\n',f"Cross val score: {score.mean()*100:.2f}%")
    print(f'\n Difference between accuracy score and cross val score {(accuracy_score(y_test,predm)-score.mean())*100:.2f}')
    print('\n')
# Out:
# ----------------- LogisticRegression() ---------------------------
#  Accuracy score for training data: 83.93
#  Accuracy score for testing data: 83.67
#
#  Confusion matrix:
#  [[246   0]
#  [ 48   0]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       246
#            1       0.00      0.00      0.00        48
#
#     accuracy                           0.84       294
#    macro avg       0.42      0.50      0.46       294
# weighted avg       0.70      0.84      0.76       294
#
#
#  Cross val score: 83.74%
#
#  Difference between accuracy score and cross val score -0.07
#
#
# ----------------- RandomForestClassifier() ---------------------------
#  Accuracy score for training data: 100.00
#  Accuracy score for testing data: 82.99
#
#  Confusion matrix:
#  [[242   4]
#  [ 46   2]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
# ...

# %% [markdown]
# # Predicting Through RandomForestClassifier

# %%
prediction_=pd.DataFrame({'predicted values':predm,'actual values':y_test})
prediction_
# Out:
#       predicted values  actual values
# 1009                 0              0
# 1262                 0              1
# 896                  0              0
# 1407                 0              0
# 1119                 0              0
# ...                ...            ...
# 123                  0              0
# 32                   0              0
# 882                  0              0
# 601                  0              0
# 792                  1              1
#
# [294 rows x 2 columns]

# %%
plt.figure(figsize=(5,5))
plt.scatter(predm,y_test, c='g')
plt1 = max(max(predm), max(y_test))
plt2 = min(min(predm), min(y_test))
plt.plot([plt1, plt2], [plt1, plt2], 'b-')
plt.xlabel('Actual Values', fontsize=15)
plt.ylabel('Predicted Values', fontsize=15)
plt.title("Random Forest Regressor")
plt.show()

# %% [markdown]
# The average price, total exchanges, and total volume are equally distributed among all the columns. For building this model, we are utilizing both regression and classification techniques. The RandomForestClassifier is the best performing model, achieving 100% accuracy.

# %% [markdown]
# # Saving The  Model

# %%
import joblib

# Create and train the model
model = RandomForestClassifier( n_estimators=100,
    criterion='gini',
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    bootstrap=True,
    random_state=42)
model.fit(X_train, y_train)

# Save the model to a file
joblib.dump(model, 'avocado_model.joblib')
# Out:
# ['avocado_model.joblib']
